# %% [markdown]
# ## Data Cleaning and Shape Examining

# %% [markdown]
# ## Home Depot Product Search Relevance

# %% [markdown]
# Shoppers rely on Home Depot’s product authority to find and buy the latest products and to get timely solutions to their home improvement needs. From installing a new ceiling fan to remodeling an entire kitchen, with the click of a mouse or tap of the screen, customers expect the correct results to their queries – quickly. Speed, accuracy and delivering a frictionless customer experience are essential.
#
# In this competition, Home Depot is asking Kagglers to help them improve their customers' shopping experience by developing a model that can accurately predict the relevance of search results.
#
# Search relevancy is an implicit measure Home Depot uses to gauge how quickly they can get customers to the right products. Currently, human raters evaluate the impact of potential changes to their search algorithms, which is a slow and subjective process. By removing or minimizing human input in search relevance evaluation, Home Depot hopes to increase the number of iterations their team can perform on the current search algorithms.

# %% [markdown]
# ### Data description

# %% [markdown]
# This data set contains a number of products and real customer search terms from Home Depot's website. The challenge is to predict a relevance score for the provided combinations of search terms and products. To create the ground truth labels, Home Depot has crowdsourced the search/product pairs to multiple human raters.
#
# The relevance is a number between 1 (not relevant) to 3 (highly relevant). For example, a search for "AA battery" would be considered highly relevant to a pack of size AA batteries (relevance = 3), mildly relevant to a cordless drill battery (relevance = 2), and not relevant to a snow shovel (relevance = 1).
#
# Each pair was evaluated by at least three human raters. The provided relevance scores are the average value of the ratings. There are three additional things to know about the ratings:
#
# The specific instructions given to the raters is provided in relevance_instructions.docx.
# Raters did not have access to the attributes.
# Raters had access to product images, while the competition does not include images.
# Your task is to predict the relevance for each pair listed in the test set. Note that the test set contains both seen and unseen search terms.

# %% [markdown]
# ### File descriptions
#
# - train.csv - the training set, contains products, searches, and relevance scores
# - test.csv - the test set, contains products and searches. You must predict the relevance for these pairs.
# - product_descriptions.csv - contains a text description of each product. You may join this table to the training or test set via the product_uid.
# - attributes.csv -  provides extended information about a subset of the products (typically representing detailed technical specifications). Not every product will have attributes.
# - sample_submission.csv - a file showing the correct submission format
# - relevance_instructions.docx - the instructions provided to human raters
#
# ### Data fields
#
# - id - a unique Id field which represents a (search_term, product_uid) pair
# - product_uid - an id for the products
# - product_title - the product title
# - product_description - the text description of the product (may contain HTML content)
# - search_term - the search query
# - relevance - the average of the relevance ratings for a given id
# - name - an attribute name
# - value - the attribute's value

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer('english')

training_data = pd.read_csv("input/train.csv.zip", encoding="ISO-8859-1")
testing_data = pd.read_csv("input/test.csv.zip", encoding="ISO-8859-1")
attribute_data = pd.read_csv('input/attributes.csv.zip')
descriptions = pd.read_csv('input/product_descriptions.csv.zip')


# training_data = pd.read_csv("../input/train.csv", encoding="ISO-8859-1")
# testing_data = pd.read_csv("../input/test.csv", encoding="ISO-8859-1")
# attribute_data = pd.read_csv('../input/attributes.csv')
# descriptions = pd.read_csv('../input/product_descriptions.csv')

# %% [markdown]
# Let's try to examing the data and try to spot if there are anything suspicious about it

# %%
len(attribute_data.product_uid.unique())
# Out:
# 86264

# %%
attribute_data.name.unique().tolist()
# Out:
# ['Bullet01',
#  'Bullet02',
#  'Bullet03',
#  'Bullet04',
#  'Bullet05',
#  'Bullet06',
#  'Bullet07',
#  'Gauge',
#  'Material',
#  'MFG Brand Name',
#  'Number of Pieces',
#  'Product Depth (in.)',
#  'Product Height (in.)',
#  'Product Weight (lb.)',
#  'Product Width (in.)',
#  'Application Method',
#  'Assembled Depth (in.)',
#  'Assembled Height (in.)',
#  'Assembled Width (in.)',
#  'Bullet08',
#  'Bullet10',
#  'Bullet18',
#  'Cleanup',
#  'Color Family',
#  'Color/Finish',
#  'Concrete Use',
#  'Container Size',
#  'Coverage Area (sq. ft.)',
#  'Deck Use',
#  'Interior/Exterior',
#  'Mildew Resistant',
#  'Opacity',
#  'Paint Product Type',
#  'Patching & Repair Product Type',
#  'Product Style',
#  'RGB Value',
#  'Sealer',
#  'Time before recoating (hours)',
#  'Tintable',
#  'Transparency',
#  'UV Resistant',
#  'Waterproof',
#  'Built-in flange',
#  'Caulkless',
#  'Certifications and Listings',
#  'Construction',
#  'Drain Included',
#  'Drain Location',
#  'Exterior bath shape',
#  'Faucet mount',
#  'Height from Floor (in.)',
#  'Installation Type',
#  'Maximum Number of Occupants',
#  'Shape',
#  'Shower Depth (in.)',
#  'Shower Height (in.)',
#  'Shower Width (in.)',
#  'Slip-resistant tub floor',
#  'Tub Depth (in.)',
#  'Tub Height (in.)',
#  'Tub Length (in.)',
#  'Tub Width (in.)',
#  'Wall Height (in.)',
#  'Water capacity (gallons)',
#  'Amperage (amps)',
#  'Charge controller included',
#  'Electrical Product Type',
#  'Inverter included',
#  'Low voltage audible alarm',
#  'Mounting frame included',
#  'Number of Panels',
#  'Panel Height (in.)',
#  'Panel length (in.)',
#  'Panel weight (lb.)',
#  'Panel Width (in.)',
#  'Portable',
#  'Solar panel type',
#  'Voltage (volts)',
#  'Wattage (watts)',
#  'Bath Faucet Type',
#  'Built-in Water Filter',
#  'Connection size (in.)',
#  'Faucet Features',
#  'Faucet Included Components',
#  'Faucet type',
#  'Flow rate (gallons per minute)',
#  'Handle type',
#  'Number of Faucet Handles',
#  'Number of showerheads',
#  'Number of Spray Settings',
#  'Showerhead face diameter (in.)',
#  'Showerhead type',
#  'Spray Pattern',
#  'Appliance Type',
#  'Bullet09',
#  'Bullet11',
#  'Bullet12',
#  'Bullet13',
#  'Bullet14',
#  'Bullet15',
#  'Bullet16',
#  'Bullet17',
#  'Capacity of Microwave (cu. ft.)',
#  'Color/Finish Family',
#  'Cut-Out Front to Back Width (in.)',
#  'Cut-Out Height (in.)',
#  'Cut-Out Left to Right Length (in.)',
#  'Door Swing/Style',
#  'Exhaust Fan Speeds',
#  'Exhaust Maximum CFM',
#  'Microwave Door Release',
#  'Microwave Features',
#  'Microwave Size',
#  'Number of One-Touch Settings',
#  'Number of Power Levels',
#  'Oven Settings',
#  'Safety Listing',
#  'Sensor Cook',
#  'Turntable',
#  'Turntable Diameter',
#  'Vent Type',
#  'Battery Power Type',
#  'Battery Size',
#  'Bulb Type Included',
#  'Commercial Light Type',
#  'Connection Type',
#  'Emergency run time (min.)',
#  'ENERGY STAR Certified',
#  'Fixture Color/Finish',
#  'Fixture Color/Finish Family',
#  'Lamp heads',
#  'Light Source',
#  'Maximum Wattage (watts)',
#  'Number of Bulbs Required',
#  'Coated',
#  'Drive Style',
#  'Driver bit included',
#  'Fastener Callout Size',
#  'Fastener Head Style',
#  'Fastener length (in.)',
#  'Fastener Plating',
#  'Fastener Thread Type',
#  'Fastener Type',
#  'Fastener/Connector Material',
#  'Finish',
#  'Finish Family',
#  'Head diameter (in.)',
#  'Head Style',
#  'Indoor/Outdoor',
#  'Measurement Standard',
#  'Package Quantity',
#  'Primary Use',
#  'Screw Length',
#  'Self drilling',
#  'Self tapping',
#  'Size',
#  'Tamper Resistant',
#  'Application',
#  'Flexible',
#  'Kits',
#  'Moisture Resistant',
#  'Moulding Features',
#  'Moulding Type',
#  'Paintable/Stainable',
#  'Pattern Number',
#  'Prefinished',
#  'Pro Pack',
#  'Product Length (in.)',
#  'Rot Resistant',
#  'Sell Pack Options',
#  'Termite Resistant',
#  'Wood Veneer',
#  'Attachable',
#  'Hardware Included',
#  'Landscape Supply Type',
#  'Width',
#  'Blade Length (In.)',
#  'Bullet20',
#  'CA (CARB) Compliant',
#  'Cutting Options',
#  'Cutting Width (in.)',
#  'Drive type',
#  'Engine Displacement (cc)',
#  'Engine Make',
#  'Features',
#  'Fuel tank capacity (gallons)',
#  'Fuel Type',
#  'Included',
#  'Lawn Mower Type',
#  'Maximum cutting height (in.)',
#  'Minimum cutting height (in.)',
#  'Mulching Capability',
#  'Number of adjustable handlebar positions',
#  'Number of Blades',
#  'Oil capacity (oz.)',
#  'Rear wheel size (in.)',
#  'Reconditioned',
#  'Size of Yard',
#  'Start Type',
#  'Terrain',
#  'Walk Behind Mower Type',
#  'Actual Blind/Shade Width (In.)',
#  'Arched',
#  'Bullet21',
#  'Cordless/Corded',
#  'Decor Product Type',
#  'Enclosure Type',
#  'Fire retardant',
#  'Front Color',
#  'Light Control',
#  'Minimum window depth required (in.)',
#  'Mount Type',
#  'Opening type',
#  'Orientation',
#  'Pre-Cut Deduction (in.)',
#  'Pre-Cut or True-to-Size Blind',
#  'Slat/vane width (in.)',
#  'Stain Resistant',
#  'Surface',
#  'Washable',
#  'Width (in) x Length (in)',
#  'Window Treatment Product Type',
#  'Kitchen Product Type',
#  'Base Spread (in.)',
#  'Ladder Height (ft.)',
#  'Ladder Rating',
#  'Ladder Type',
#  'Ladders/Scaffolding Features',
#  'Load weight capacity',
#  'Nonslip tread',
#  'Number of Steps',
#  'Rung/Step Depth',
#  'Step rise (in.)',
#  'Fence Application',
#  'Garden Fencing Type',
#  'Approximate Depth (ft.)',
#  'Approximate Width (ft.)',
#  'Frame Material',
#  'Outdoor Living Product Type',
#  'Corrosion Resistant',
#  'Metal Stock Type',
#  'Perforated',
#  'Product Thickness (in.)',
#  'Weldable',
#  'Capacity (gallons)',
#  'Spout Length (in.)',
#  'Finish Type',
#  'Paneling/Planking Features',
#  'Paneling/Planking Style',
#  'Paneling/Planking Type',
#  'Quantity',
#  'Fixture Material',
#  'Linkable',
#  'Mounting Method',
#  'Slim line',
#  'Under Cabinet Light Type',
#  'Irrigated',
#  'Irrigation System Component',
#  'Maximum Coverage Area (sq ft.)',
#  'Maximum Spray Distance (ft.)',
#  'Pressure Rating',
#  'Product Diameter (in.)',
#  'Retracted Height (in.)',
#  'Retraction Spring',
#  'Riser Required',
#  'Sprinkler Location',
#  'Sprinkler Type',
#  'Capacity - Washer (cu. ft.)',
#  'Capacity- Front Load Washer (cu ft)',
#  'Control Type',
#  'Cycle - Allergen',
#  'Depth With Door Open 90 Degrees (In)',
#  'Door Opening Height (In.)',
#  'Door Opening Width (In.)',
#  'Door Style',
#  'Energy Consumption (kWh/year)',
#  'Energy Efficiency Tier Rating',
#  'High Efficiency Washer',
#  'High-Efficiency Detergent Required',
#  'Included Items',
#  'Maximum Spin Speed (RPM)',
#  'Number of Rinse Cycles',
#  'Number of Rinse Temperatures',
#  'Number of Wash Cycles',
#  'Number of Wash Speeds',
#  'Number of Wash Temperatures',
#  'Pedestal Model#',
#  'Stackable',
#  'Stacking Kit Model#',
#  'Steam Function',
#  'Wash Cycles',
#  'Washer Dispensers',
#  'Washer Features',
#  'Washer Interior Light',
#  'Washer Tub/Drum Material',
#  'Compression strength (psi)',
#  'Mix Type',
#  'Vertical/overhead use',
#  'Working time (min.)',
#  'Storage Product Type',
#  'Base Required',
#  'Concrete Type',
#  'Packaging Type',
#  'Square Feet per Piece',
#  'Textured',
#  'Vehicular Traffic Rated',
#  'Friction Fit',
#  'Insulation Type',
#  'Product Length (ft.)',
#  'Sheet or Roll',
#  'Coating Product Category',
#  'Paint/Stain Key Features',
#  'Paint/Stain/Waterproofer Product Type',
#  'Sheen',
#  'Specialty Finish',
#  'Bag Capacity/Dry Volume (cu. ft.)',
#  'Bag Weight (lb.)',
#  'Rock Size',
#  'Rock Type',
#  'Durability',
#  'Brush width (in.)',
#  'Concrete Tool Type',
#  'Handle Length (in.)',
#  'Atomic Clock',
#  'Batteries Included',
#  'Battery Type Required',
#  'Clock display type',
#  'Clock face length (in.)',
#  'Clock face width (in.)',
#  'Clock Type',
#  'Color',
#  'Date display',
#  'Deco Style',
#  'Multiple time zones',
#  'Number of Batteries Required',
#  'Quartz movement',
#  'Assembly Required',
#  'Number of Compartments',
#  'Feet',
#  'Included Accessories',
#  'Number of inside pockets',
#  'Number of outside pockets',
#  'Shoulder strap',
#  'Tape Holder',
#  'Tool Storage Product Type',
#  'Tools Product Type',
#  'Wheels',
#  'Zippered Top',
#  'Battery Amp Hours',
#  'Charger Included',
#  'Cordless Tool Type',
#  'Drive Size (in.)',
#  'Forward/Reverse Rocker Switch',
#  'Impacts Per Minute',
#  'Maximum Speed (rpm)',
#  'Number of Batteries Included',
#  'Power Tool Features',
#  'Power Tool Product Type',
#  'Torque (lb-in)',
#  'Area Heated (Sq. Ft.)',
#  'Burner System',
#  'Firebox depth (in.)',
#  'Firebox height (in.)',
#  'Firebox width (in.)',
#  'Fuel type',
#  'Mount type',
#  'Vented or Vent-Free',
#  'Actual panel height (in.)',
#  'Actual panel thickness (in.)',
#  'Actual panel width (in.)',
#  'Cap/top included',
#  'Commercial/Residential Use',
#  'Fencing Product Type',
#  'Fencing Style',
#  'Nominal panel depth (in.)',
#  'Nominal panel height (ft.)',
#  'Nominal panel width (ft.)',
#  'Number of pickets for panels',
#  'Number of rails for panels',
#  'Panel Assembly',
#  'Recommended Fastener',
#  'Structure type',
#  'UV Protected',
#  'Bowl Height',
#  'Bowl Height (in.)',
#  'Bowl Shape',
#  'Commercial / Residential',
#  'Flush Valve Size (in.)',
#  'Flushing Mechanism',
#  'Flushing Technology',
#  'Flushing Type',
#  'Gallons Per Flush',
#  'MaP Performance Rating',
#  'Mount Location',
#  'Rough In Size',
#  'Toilet Features',
#  'Toilet Included Components',
#  'Trip Lever Location',
#  'Collection Name',
#  'Number in Pack',
#  'Shade Type',
#  'Builders Hardware Product Type',
#  'Cabinet Pull Type',
#  'Center to Center Measurement (inches)',
#  'Center to Center Measurement (mm)',
#  'Hardware Finish Family',
#  'Projection',
#  'Pull height (in.)',
#  'Pull Length (in.)',
#  'Style',
#  'Actual post height (in.)',
#  'Actual post thickness (in.)',
#  'Actual post width (in.)',
#  'Number of posts included',
#  'Use',
#  'Maximum ladder length (ft.)',
#  'Maximum reach (ft.)',
#  'Minimum ladder length (ft.)',
#  'Coating Base',
#  'Coating Consistency',
#  'Container type',
#  'Dry Time',
#  'Fire Rating',
#  'Roofing Product Type',
#  'Surface Recommended',
#  'Care Instructions',
#  'Chair Type',
#  'Cushion Color Family',
#  'Cushion Color or Pattern',
#  'Fill Material',
#  'Frame Primary Finish',
#  'Patio Furniture Features',
#  'Seat Height (in.)',
#  'Weight Capacity (lb.)',
#  'Canopy Color',
#  'Canopy Shape',
#  'Opening Mechanism',
#  'Pattern Style',
#  'Pole Color',
#  'Pole Diameter (in.)',
#  'Pole Material',
#  'Rib Material',
#  'Umbrella Canopy Diameter (ft.)',
#  'Umbrella Canopy Material',
#  'Umbrella Height (in.)',
#  'Umbrella Type',
#  'Diameter (in.)',
#  'Grade',
#  'Type',
#  'Commercial',
#  'Door Configuration',
#  'Door Handing',
#  'Door Material',
#  'Door Size (WxH) in.',
#  'Door Thickness (in.)',
#  'Door Type',
#  'Energy Star Qualified',
#  'Finished Opening Height (in.)',
#  'Finished Opening Width (in.)',
#  'Fire rating',
#  'Glass Caming Finish',
#  'Glass Style',
#  'Glass Type',
#  'Hinge Finish',
#  'Jamb Size (in.)',
#  'Number of Hinges',
#  'Panel Type',
#  'Rough Opening Height',
#  'Rough Opening Width',
#  'Extension length (in.)',
#  'Handle Type',
#  'Housing Material',
#  'Kitchen Faucet Type',
#  'Number of Faucet Holes Required',
#  'Spout height (in.)',
#  'Spout Reach (in.)',
#  'Spout Type',
#  'Touchless/Touch On',
#  'Valve material',
#  'Concentrated',
#  'Ice Melt Features',
#  'Lowest effective temperature (F)',
#  'Package size (gallons)',
#  'Product Form',
#  'Faced or Unfaced',
#  'Formaldehyde Free',
#  'Insulation Application Type',
#  'Insulation R-Value',
#  'Roll or Batt',
#  'Vapor Retardent',
#  'Battery Life (hours)',
#  'Bulb Type',
#  'Casing material',
#  'Flashlight Features',
#  'Flashlight type',
#  'Lumens',
#  'Power Source',
#  'Safety & Security Product Type',
#  'Container Height (in.)',
#  'Container Length (in.)',
#  'Container Width (in.)',
#  'Planter Features',
#  'Accessory type',
#  'Stair Part Type',
#  'Bullet Proof',
#  'Mirrored',
#  'Non-Glare',
#  'Shatter Resistant',
#  'Sheet Features',
#  'Surface Type',
#  'Dishwasher drain connection',
#  'Disposer Feed',
#  'Grind chamber capacity (oz.)',
#  'Grinding Speed (RPM)',
#  'Horsepower (hp)',
#  'Noise insulation',
#  'Stainless steel grind chamber',
#  'Antimicrobial',
#  'Approximate Tile Size',
#  'Coverage Area (sq. ft./case)',
#  'Flooring Product Type',
#  'Installable over Cork Underlayment',
#  'Mark Resistant',
#  'Product Thickness (mm)',
#  'Sample',
#  'Scratch Resistant',
#  'Skid Resistant',
#  'Vinyl Surface Type',
#  'Package Size (lb.)',
#  'Application Type',
#  'Gas Type',
#  'Maximum Temperature  (F)',
#  'Minimum Temperature (F)',
#  'Recovery Rate at 90F Rise (gallons/hour)',
#  'Tank Capacity (gallons)',
#  'Tank Valve Size (in.)',
#  'Water Connection Location',
#  'Water Connection Size (in.)',
#  'Water Heater Features',
#  'Water Heater Profile',
#  'Bag Change/Receptacle Full Indicator',
#  'Bagless',
#  'Carpet Height Adjustments',
#  'Cleaning Range with Tools(ft.)',
#  'Cord Length (ft.)',
#  'Dust Compression System',
#  'Edge Cleaner',
#  'Filter Type',
#  'Headlights',
#  'Number of Attachments',
#  'Number of Filters',
#  'Pet Attachment',
#  'Retractable Cord',
#  'LowE rating',
#  'Approximate Rug Size',
#  'Area Rug Pattern',
#  'Area Rug Style',
#  'Backing material',
#  'Cleaning instructions',
#  'Pile height (in.)',
#  'Rug Material',
#  'Rug Shape',
#  'Rug Weave',
#  'Contact Type Allowed',
#  'Nominal post height (ft.)',
#  'Nominal post thickness (in.)',
#  'Nominal post width (in.)',
#  'Pressure Treated',
#  'Stainable/Paintable',
#  'Compatible Pipe Material',
#  'Fitting or Connector Type',
#  'Left Side Connection',
#  'Left Side Inlet',
#  'Left Side Size',
#  'Maximum working pressure (psi)',
#  'Pipe or Fitting Product Type',
#  'Push to connect',
#  'Right Side Connection',
#  'Right Side Size',
#  'Capacity (cu. Ft.) - Freezer',
#  'Capacity (cu. Ft.) - Fresh Food',
#  'Capacity (cu. ft.) - Refrigerators',
#  'Capacity (cu. Ft.) - Total',
#  'Color - Appliance Cabinet',
#  'Color - Door Handle(s)',
#  'Counter Depth (Yes/No)',
#  'Defrost Type',
#  'Depth (Excluding Handles)',
#  'Depth (Including Handles)',
#  'Depth (Less Door)',
#  'Door Finish',
#  'Freezer Door Type',
#  'Freezer Features',
#  'General Features',
#  'Height to Top of Door Hinge',
#  'Height to Top of Refrigerator (in.)',
#  'Ice Maker',
#  'Ice Maker Features',
#  'Ice/Water Dispenser',
#  'Number of Doors',
#  'Number of Freezer Shelves',
#  'Number of Fresh Food Shelves',
#  'Operational Features',
#  'Refrigeration Dispenser Features',
#  'Refrigerator Width (In.)',
#  'Shelf Material - Freezer',
#  'Shelf Material - Refrigerator',
#  'Storage Features',
#  'Temperature Control Type',
#  nan,
#  'Capacity (lb.)',
#  'Fits brands/models',
#  'Number of Shelves',
#  'Number of Drawers',
#  'Removable Shelves',
#  'Storage Capacity (cu. ft.)',
#  'Light transmittal',
#  'Locking system',
#  'Thickness (In.)',
#  'Window Well Part',
#  'Shade material strength',
#  'Size Ordering Options',
#  'Chemical resistant',
#  'Dry to touch (min.)',
#  'Interior Paint & Stains Product Type',
#  'Number of components in formula',
#  'Paint/Stain Base Material',
#  'Paint/Stain Clean Up',
#  'Primer required',
#  'Substrate/Surface Use Type',
#  'Drive surface width (in.)',
#  'Total weight capacity (lb.)',
#  'Tread',
#  'Vehicle lift (in.)',
#  'Maximum ceiling height (ft.)',
#  'Minimum ceiling height (ft.)',
#  'Recessed Opening Height (In.)',
#  'Recessed Opening Width (In.)',
#  'Adjustable Spray Pattern',
#  'Body Material',
#  'Commercial Grade',
#  'Fitting Size',
#  'Handle Grip Material',
#  'Hot Water Use',
#  'Insulated Handle',
#  'Maximum Pressure (PSI)',
#  'Set',
#  'Trigger Lock',
#  'Wand',
#  'Water Flow Control',
#  'A/C Cooling Rate (BTU/hr)',
#  'A/C Coverage Area (sq. ft.)',
#  'Air Conditioner Product Type',
#  'Air direction/circulation',
#  'Automatic shutoff',
#  'BTU Cooling Rating',
#  'Controls',
#  'Decibel Rating',
#  'Decibel Rating (Indoor)',
#  'Decibel Rating (Outdoor)',
#  'Energy Efficiency Ratio (EER)',
#  'Filter light reminder',
#  'Heater included',
#  'Number of cool settings',
#  'Number of Fan Speeds',
#  'Remote Control',
#  'Sleep setting',
#  'Timer',
#  'Window opening maximum width (in.)',
#  'Window opening minimum height (in.)',
#  'Window opening minimum width (in.)',
#  'Adjustable Speed',
#  'Discharge Flow @ 0 ft. (gallons/hour)',
#  'Discharge Flow @ 10 ft. (gallons/hour)',
#  'Float Switch',
#  'Head Pressure (ft.)',
#  'Inlet Connection',
#  'Maximum Discharge Flow (gallons/hour)',
#  'Maximum Pumping Height (ft.)',
#  'Maximum Working Temperature (F)',
#  'Minimum working temperature (F)',
#  'Outlet Connection',
#  'Pool Cover Pump',
#  'Power Type',
#  'Power Type Required',
#  'Pump Switch Type',
#  'Run-Dry Capable',
#  'Self-Priming',
#  'Submersible',
#  'Waterfall Pump',
#  'Dries clear',
#  'Dry to the touch (hours)',
#  'Number of coats recommended',
#  'Product Size (oz.)',
#  'UV Protection',
#  'Chuck Size',
#  'Chuck Type',
#  'Variable Speed',
#  'Auger diameter (in.)',
#  'Chute rotation turning radius (Deg)',
#  'Clearing Surface Type',
#  'Clearing tool included',
#  'Clearing Width (In.)',
#  'Drive System',
#  'Engine torque (ft.-lb.)',
#  'Engine Type',
#  'Ideal Snow Depth (In.)',
#  'Impeller diameter (in.)',
#  'Intake height (in.)',
#  'Number of Forward Speeds',
#  'Number of Reverse Speeds',
#  'Recommended Oil type',
#  'Rust Resistant',
#  'Snow Blower Features',
#  'Snow Blower Usage',
#  'Snow Equipment Product Type',
#  'Tire height (in.)',
#  'Tire width (in.)',
#  'Traction',
#  'Type of Snow',
#  'Broiler Burner Rating (BTU)',
#  'Broiler Location',
#  'Burner Grate Material',
#  'Burner No.1 BTU',
#  'Burner No.2 BTU',
#  'Burner No.3 BTU',
#  'Burner No.4 BTU',
#  'Burner No.5 BTU',
#  'Burner No.6 BTU',
#  'Capacity of Oven (cu. ft.)',
#  'Cleaning Type',
#  'Color of Cooktop',
#  'Convection',
#  'Convection Type',
#  'Cooktop Features',
#  'Cooktop Surface Type',
#  'Downdraft Exhaust',
#  'Ignition Type',
#  'Item Package UOM',
#  'Number of Burners',
#  'Oven Cleaning Options',
#  'Oven Features',
#  'Oven Racks',
#  'Range Size',
#  'Range Type',
#  'Chair Depth (in.)',
#  'Chair Height (in.)',
#  'Chair Height Type',
#  'Chair Width (in.)',
#  'Seating Capacity',
#  'Set Includes',
#  'Table Finish',
#  'Table Height (in.)',
#  'Table Length (in.)',
#  'Table Primary Finish',
#  'Table Shape',
#  'Table Width (in.)',
#  'Tabletop Material',
#  'Power Tool Accessory Type',
#  'Adhesion level',
#  'Adhesive Product Type',
#  'Maximum application temperature (F)',
#  'Minimum application temperature (F)',
#  'Number of rolls included',
#  'Product Weight (oz.)',
#  'Recommended surfaces',
#  'Removal time (days)',
#  'Roll length (ft.)',
#  'UV/sunlight resistant',
#  'Electrical Tool Type',
#  'Insulated',
#  'Caulk Form',
#  'Caulk Type',
#  'Coverage (linear ft.)',
#  'Cure time (hours)',
#  'Dry color family',
#  'Fire and high heat resistant',
#  'Individual size (oz.)',
#  'Longevity (years)',
#  'Mold and mildew resistant',
#  'Permanently flexible',
#  'Professional Paint Supplies & Values',
#  'Number of Tools Included',
#  'Tools Included',
#  'Bag/maximum load capacity (bushels)',
#  'Chipper blade material',
#  'Chipper capacity (in.)',
#  'Cord lock',
#  'Feed capacity (in.)',
#  'Maximum extension cord length (ft.)',
#  'Required extension cord rating',
#  'Self-Feeding',
#  'Area of Use',
#  'Concentrated or Ready to Use',
#  'Contact or systemic',
#  'Container Size (oz.)',
#  'Coverage area (sq. ft)',
#  'Equivalent ready to use amount',
#  'Extended Control',
#  'Fertilizer component',
#  'Form',
#  'Organic',
#  'Pet and livestock friendly',
#  'Post-emergent',
#  'Pre-emergent',
#  'Safe for Edibles',
#  'Weed Type',
#  'Automatic line-advance system',
#  'Fits brands',
#  'Recommended line diameter (in.)',
#  'Shaft type',
#  'Trimmer Attachment Type',
#  'Trimmer head type',
#  'Weatherable',
#  'Package quantity',
#  'Brand/Model Compatibility',
#  'Vacuum Accessory Type',
#  'Light Bulb Base Type',
#  'Biodegradable',
#  'Straw Type',
#  'Casters',
#  'Drain hose connection',
#  'Hose Exhaust',
#  'Moisture removal capacity (pints/day)',
#  'Self-diagnostic tools',
#  'Vent hose configuration',
#  'Window venting kit included',
#  'Adjustable Shelves',
#  'Blade cutting type',
#  'Blade Material',
#  'Coated Blades',
#  'Forged Blade',
#  'Garden Center Tool Type',
#  'Gear Driven',
#  'Handle Material',
#  'Maximum Cutting Thickness (in.)',
#  'Rotating Head',
#  'Sap Groove',
#  'Saw Attachment',
#  'Telescoping Handle',
#  'Tool Type',
#  'Applicator/Tool Type',
#  'Brush head height (in.)',
#  'Brush head material',
#  'Brush head width (in.)',
#  'Head shape(s)',
#  'Corded Tool Type',
#  'Dust collection type',
#  'Pad description',
#  'Speed  (rpm)',
#  'Tool-less conversion',
#  'Adjustable Lamp Head',
#  'Shade Color Family',
#  'Shade Material',
#  'Hook diameter (in.)',
#  'Hook length (in.)',
#  'Hook opening (in.)',
#  'Magnetic',
#  'Maximum Weight Capacity (lb.)',
#  'Projection (in.)',
#  'Self-adhesive',
#  'Adjustable flow rate',
#  'Cover Plate Included',
#  'Handles included',
#  'Soap Dispenser Included',
#  'Supply lines included',
#  'Accessory Type',
#  'Air Tool Type',
#  'Assembled Length (in.)',
#  'NIOSH classification',
#  'Quantity per package',
#  'Quick release',
#  'Respirator type',
#  'Safety & Accessories Product Type',
#  'Pest Type',
#  'Safe for Pets',
#  'Base Color/Finish Family',
#  'California Title 20 Compliant',
#  'Harp Style',
#  'Maximum Bulb Wattage',
#  'Primary Switch Type',
#  'Shade Diameter (in.)',
#  'Shade Shape',
#  'Switch Mechanism',
#  'Actual product thickness (in.)',
#  'Actual product width (in.)',
#  'Nominal Product H x W (In.)',
#  'Nominal Product Height (In.)',
#  'Nominal Product Length (ft.)',
#  'Nominal product width (in.)',
#  'Texture',
#  'Density',
#  'Unspooled Length (ft.)',
#  'Bypass valve',
#  'Filter change indicator',
#  'Filtration method',
#  'Fitting size (in.)',
#  'Fitting style',
#  'Installation kit included',
#  'Maximum feed water pressure (psi)',
#  'Maximum feed water temperature (F)',
#  'Maximum filtered water flow (gallons per min.)',
#  'Minimum feed water pressure (psi)',
#  'Minimum feed water temperature (F)',
#  'Number of stages',
#  'UV lamp',
#  'Water Filtration System Type',
#  'Water Filtration Technology',
#  'Approximate Lightbulb Length',
#  'Average Life (hours)',
#  'Bulb Diameter (In.)',
#  'Bulb Shape',
#  'Light Bulb Base Code',
#  'Light Bulb Features',
#  'Light Bulb Shape Code',
#  'Light Color',
#  'Light Output (lumens)',
#  'Lighting Technology',
#  'Number in Package',
#  'Specialty Bulb Type',
#  'Watt Equivalence',
#  'Arbor included',
#  'Bit Material',
#  'Drill Bit Type',
#  'Drill Bit Type(s) Included',
#  'Individual/Set',
#  'Material Cut',
#  'Min Chuck Size Required',
#  'Pilot Bit Included',
#  'Shank Style',
#  'Brace type',
#  'Fasteners included',
#  'Number of mounting holes',
#  'Square Feet per Box (sq.ft.)',
#  'Product Type',
#  'Break Strength (lb.)',
#  'Exact Dry SCOF Rating',
#  'Exact Wet SCOF Rating',
#  'Glazed',
#  'Number of Tiles per Case',
#  'Style Type',
#  'Suggested Grout Line Size',
#  'Tile Features',
#  'Tile Finish',
#  'Tile Material',
#  'Tile Use',
#  'Chemical retention (lb./cu. ft.)',
#  'Fastener recommendation',
#  'Lumber quality',
#  'Type of Pressure Treatment',
#  'Water Resistant',
#  'Fits models',
#  'Used with equipment type',
#  'Electrical Features',
#  'Number of Poles',
#  'Number of Switches',
#  'Switch Style',
#  'Switch Type',
#  'Wall Plate Included',
#  'Accessories Included',
#  'Fuel Gauge',
#  'Heat rating (BTU/hour)',
#  'Heater Type',
#  'Heating Product Type',
#  'Heating Technology Type',
#  'Installation',
#  'Power/Fuel Type',
#  'Room Size (sq. ft.)',
#  'Thermostat',
#  'Timer Included',
#  'Vented',
#  'Cutting capacity (in.)',
#  'Shock-Absorbing Bumper',
#  'Telescoping Handles',
#  'Basin Depth (in.)',
#  'Basin Length (in.)',
#  'Basin Width (in.)',
#  'Faucet Hole Spacing (in.)',
#  'Faucet Included',
#  'Inner bowl front to back length (in.)',
#  'Inner bowl side to side width (in.)',
#  'Overflow location',
#  'Pedestal material',
#  'Curing time (hours)',
#  'Drillable',
#  'Flammable',
#  'Glue/epoxy type',
#  'Sandable',
#  'Set Time (Min.)',
#  'Solvent resistant',
#  'Compressor/Air Tool Features',
#  'Energy Type',
#  'Loading type',
#  'Maximum Fastener Size',
#  'Minimum Fastener Size',
#  'Minimum Recommended Air Delivery SCFM @ 90PSI',
#  'Minimum Recommended Operating Pressure (psi)',
#  'Nail Gauge',
#  'Nailgun Angle',
#  'Blade Diameter',
#  ...]

# %%
test =  pd.merge(training_data, attribute_data, on='product_uid', how="left")

# %%
test
# Out:
#              id  product_uid  \
# 0             2       100001
# 1             2       100001
# 2             2       100001
# 3             2       100001
# 4             2       100001
# 5             2       100001
# 6             2       100001
# 7             2       100001
# 8             2       100001
# 9             2       100001
# 10            2       100001
# 11            2       100001
# 12            2       100001
# 13            2       100001
# 14            2       100001
# 15            3       100001
# 16            3       100001
# 17            3       100001
# 18            3       100001
# 19            3       100001
# 20            3       100001
# 21            3       100001
# 22            3       100001
# 23            3       100001
# 24            3       100001
# 25            3       100001
# 26            3       100001
# 27            3       100001
# 28            3       100001
# 29            3       100001
# ...         ...          ...
# 1428122  221473       206650
# 1428123  221473       206650
# 1428124  221473       206650
# 1428125  221473       206650
# 1428126  221473       206650
# 1428127  221473       206650
# 1428128  221473       206650
# 1428129  221473       206650
# 1428130  221473       206650
# 1428131  221473       206650
# 1428132  221473       206650
# 1428133  221473       206650
# 1428134  221473       206650
# 1428135  221473       206650
# 1428136  221473       206650
# 1428137  221473       206650
# 1428138  221473       206650
# 1428139  221473       206650
# 1428140  221473       206650
# 1428141  221473       206650
# 1428142  221473       206650
# 1428143  221473       206650
# 1428144  221473       206650
# 1428145  221473       206650
# 1428146  221473       206650
# 1428147  221473       206650
# 1428148  221473       206650
# 1428149  221473       206650
# 1428150  221473       206650
# 1428151  221473       206650
#
#                                              product_title  \
# 0                        Simpson Strong-Tie 12-Gauge Angle
# 1                        Simpson Strong-Tie 12-Gauge Angle
# 2                        Simpson Strong-Tie 12-Gauge Angle
# 3                        Simpson Strong-Tie 12-Gauge Angle
# 4                        Simpson Strong-Tie 12-Gauge Angle
# 5                        Simpson Strong-Tie 12-Gauge Angle
# 6                        Simpson Strong-Tie 12-Gauge Angle
# 7                        Simpson Strong-Tie 12-Gauge Angle
# 8                        Simpson Strong-Tie 12-Gauge Angle
# 9                        Simpson Strong-Tie 12-Gauge Angle
# 10                       Simpson Strong-Tie 12-Gauge Angle
# 11                       Simpson Strong-Tie 12-Gauge Angle
# 12                       Simpson Strong-Tie 12-Gauge Angle
# 13                       Simpson Strong-Tie 12-Gauge Angle
# 14                       Simpson Strong-Tie 12-Gauge Angle
# 15                       Simpson Strong-Tie 12-Gauge Angle
# 16                       Simpson Strong-Tie 12-Gauge Angle
# 17                       Simpson Strong-Tie 12-Gauge Angle
# 18                       Simpson Strong-Tie 12-Gauge Angle
# 19                       Simpson Strong-Tie 12-Gauge Angle
# 20                       Simpson Strong-Tie 12-Gauge Angle
# 21                       Simpson Strong-Tie 12-Gauge Angle
# 22                       Simpson Strong-Tie 12-Gauge Angle
# 23                       Simpson Strong-Tie 12-Gauge Angle
# 24                       Simpson Strong-Tie 12-Gauge Angle
# 25                       Simpson Strong-Tie 12-Gauge Angle
# 26                       Simpson Strong-Tie 12-Gauge Angle
# 27                       Simpson Strong-Tie 12-Gauge Angle
# 28                       Simpson Strong-Tie 12-Gauge Angle
# 29                       Simpson Strong-Tie 12-Gauge Angle
# ...                                                    ...
# 1428122  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428123  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428124  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428125  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428126  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428127  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428128  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428129  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428130  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428131  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428132  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428133  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428134  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428135  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428136  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428137  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428138  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428139  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428140  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428141  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428142  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428143  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428144  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428145  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428146  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428147  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428148  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428149  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428150  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
# 1428151  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
#
#                           search_term  relevance  \
# 0                       angle bracket       3.00
# 1                       angle bracket       3.00
# 2                       angle bracket       3.00
# 3                       angle bracket       3.00
# 4                       angle bracket       3.00
# 5                       angle bracket       3.00
# 6                       angle bracket       3.00
# 7                       angle bracket       3.00
# 8                       angle bracket       3.00
# 9                       angle bracket       3.00
# 10                      angle bracket       3.00
# 11                      angle bracket       3.00
# 12                      angle bracket       3.00
# 13                      angle bracket       3.00
# 14                      angle bracket       3.00
# 15                          l bracket       2.50
# 16                          l bracket       2.50
# 17                          l bracket       2.50
# 18                          l bracket       2.50
# 19                          l bracket       2.50
# 20                          l bracket       2.50
# 21                          l bracket       2.50
# 22                          l bracket       2.50
# 23                          l bracket       2.50
# 24                          l bracket       2.50
# 25                          l bracket       2.50
# 26                          l bracket       2.50
# 27                          l bracket       2.50
# 28                          l bracket       2.50
# 29                          l bracket       2.50
# ...                               ...        ...
# 1428122  fine sheer curtain 63 inches       2.33
# 1428123  fine sheer curtain 63 inches       2.33
# 1428124  fine sheer curtain 63 inches       2.33
# 1428125  fine sheer curtain 63 inches       2.33
# 1428126  fine sheer curtain 63 inches       2.33
# 1428127  fine sheer curtain 63 inches       2.33
# 1428128  fine sheer curtain 63 inches       2.33
# 1428129  fine sheer curtain 63 inches       2.33
# 1428130  fine sheer curtain 63 inches       2.33
# 1428131  fine sheer curtain 63 inches       2.33
# 1428132  fine sheer curtain 63 inches       2.33
# 1428133  fine sheer curtain 63 inches       2.33
# 1428134  fine sheer curtain 63 inches       2.33
# 1428135  fine sheer curtain 63 inches       2.33
# 1428136  fine sheer curtain 63 inches       2.33
# 1428137  fine sheer curtain 63 inches       2.33
# 1428138  fine sheer curtain 63 inches       2.33
# 1428139  fine sheer curtain 63 inches       2.33
# 1428140  fine sheer curtain 63 inches       2.33
# 1428141  fine sheer curtain 63 inches       2.33
# 1428142  fine sheer curtain 63 inches       2.33
# 1428143  fine sheer curtain 63 inches       2.33
# 1428144  fine sheer curtain 63 inches       2.33
# 1428145  fine sheer curtain 63 inches       2.33
# 1428146  fine sheer curtain 63 inches       2.33
# 1428147  fine sheer curtain 63 inches       2.33
# 1428148  fine sheer curtain 63 inches       2.33
# 1428149  fine sheer curtain 63 inches       2.33
# 1428150  fine sheer curtain 63 inches       2.33
# 1428151  fine sheer curtain 63 inches       2.33
#
#                                   name  \
# 0                             Bullet01
# 1                             Bullet02
# 2                             Bullet03
# 3                             Bullet04
# 4                             Bullet05
# 5                             Bullet06
# 6                             Bullet07
# 7                                Gauge
# 8                             Material
# 9                       MFG Brand Name
# 10                    Number of Pieces
# 11                 Product Depth (in.)
# 12                Product Height (in.)
# 13                Product Weight (lb.)
# 14                 Product Width (in.)
# 15                            Bullet01
# 16                            Bullet02
# 17                            Bullet03
# 18                            Bullet04
# 19                            Bullet05
# 20                            Bullet06
# 21                            Bullet07
# 22                               Gauge
# 23                            Material
# 24                      MFG Brand Name
# 25                    Number of Pieces
# 26                 Product Depth (in.)
# 27                Product Height (in.)
# 28                Product Weight (lb.)
# 29                 Product Width (in.)
# ...                                ...
# 1428122                       Bullet01
# 1428123                       Bullet02
# 1428124                       Bullet03
# 1428125                       Bullet04
# 1428126                       Bullet05
# 1428127                       Bullet06
# 1428128                   Color Family
# 1428129                   Color/Finish
# 1428130                     Deco Style
# 1428131             Decor Product Type
# 1428132                 Fabric surface
# 1428133                       Features
# 1428134                 Fire retardant
# 1428135                  Hanging Style
# 1428136                       Included
# 1428137                 Indoor/Outdoor
# 1428138                      Insulated
# 1428139          Light Filtering Level
# 1428140               Machine Washable
# 1428141                       Material
# 1428142                 MFG Brand Name
# 1428143                  Pattern/theme
# 1428144            Product Depth (in.)
# 1428145           Product Height (in.)
# 1428146           Product Length (in.)
# 1428147           Product Weight (lb.)
# 1428148            Product Width (in.)
# 1428149       Width (in) x Length (in)
# 1428150  Window Treatment Product Type
# 1428151              Wrinkle resistant
#
#                                                      value
# 0        Versatile connector for various 90° connection...
# 1        Stronger than angled nailing or screw fastenin...
# 2        Help ensure joints are consistently straight a...
# 3                    Dimensions: 3 in. x 3 in. x 1-1/2 in.
# 4                                 Made from 12-Gauge steel
# 5                Galvanized for extra corrosion resistance
# 6        Install with 10d common nails or #9 x 1-1/2 in...
# 7                                                       12
# 8                                         Galvanized Steel
# 9                                       Simpson Strong-Tie
# 10                                                       1
# 11                                                     1.5
# 12                                                       3
# 13                                                    0.26
# 14                                                       3
# 15       Versatile connector for various 90° connection...
# 16       Stronger than angled nailing or screw fastenin...
# 17       Help ensure joints are consistently straight a...
# 18                   Dimensions: 3 in. x 3 in. x 1-1/2 in.
# 19                                Made from 12-Gauge steel
# 20               Galvanized for extra corrosion resistance
# 21       Install with 10d common nails or #9 x 1-1/2 in...
# 22                                                      12
# 23                                        Galvanized Steel
# 24                                      Simpson Strong-Tie
# 25                                                       1
# 26                                                     1.5
# 27                                                       3
# 28                                                    0.26
# 29                                                       3
# ...                                                    ...
# 1428122                  Sheer panel, gently filters light
# 1428123                           No header pole top panel
# 1428124                                   Machine washable
# 1428125                Wide array of colors to choose from
# 1428126                                     100% polyester
# 1428127                           Contains 1-curtain panel
# 1428128                                              Green
# 1428129                                          Pool Blue
# 1428130                                             Modern
# 1428131                                   Window Treatment
# 1428132                                     100% Polyester
# 1428133                                   Machine washable
# 1428134                                                 No
# 1428135                                         Rod Pocket
# 1428136                       No Additional Items Included
# 1428137                                             Indoor
# 1428138                                                 No
# 1428139                                              Sheer
# 1428140                                                Yes
# 1428141                                          Polyester
# 1428142                                        LICHTENBERG
# 1428143                            Heathered Texture Sheer
# 1428144                                                0.1
# 1428145                                                 .1
# 1428146                                                 63
# 1428147                                               0.66
# 1428148                                                 40
# 1428149                                            40 x 63
# 1428150                                      Drapery Panel
# 1428151                                                 No
#
# [1428152 rows x 7 columns]

# %%
test.isna().sum()
# Out:
# id                   0
# product_uid          0
# product_title        0
# search_term          0
# relevance            0
# name             17520
# value            18820
# dtype: int64

# %%
test.notna().sum()
# Out:
# id               1428152
# product_uid      1428152
# product_title    1428152
# search_term      1428152
# relevance        1428152
# name             1410632
# value            1409332
# dtype: int64

# %%
test.isna().sum() - test.notna().sum()
# Out:
# id              -1428152
# product_uid     -1428152
# product_title   -1428152
# search_term     -1428152
# relevance       -1428152
# name            -1393112
# value           -1390512
# dtype: int64

# %%
print("training data shape is:",training_data.shape)
print("testing data shape is:",testing_data.shape)
print("attribute data shape is:",attribute_data.shape)
print("description data shape is:",descriptions.shape)

# %%
print("training data has empty values:",training_data.isnull().values.any())
print("testing data has empty values:",testing_data.isnull().values.any())
print("attribute data has empty values:",attribute_data.isnull().values.any())
print("description data has empty values:",descriptions.isnull().values.any())

# %%
training_data.head(10)

# %%
print("there are in total {} products ".format(len(training_data.product_title.unique())))
print("there are in total {} search query ".format(len(training_data.search_term.unique())))
print("there are in total {} product_uid".format(len(training_data.product_uid.unique())))

# %%
testing_data.head(10)

# %%
print("there are in total {} products ".format(len(testing_data.product_title.unique())))
print("there are in total {} search query ".format(len(testing_data.search_term.unique())))
print("there are in total {} product_uid".format(len(testing_data.product_uid.unique())))

# %%
attribute_data.head(10)

# %%
print("there are in total {} product_uid ".format(len(attribute_data.product_uid.unique())))
print("there are in total {} names ".format(len(attribute_data.name.unique())))
print("there are in total {} values".format(len(attribute_data.value.unique())))

# %%
descriptions.head(10)

# %%
print("there are in total {} product_uid ".format(len(descriptions.product_uid.unique())))
print("there are in total {} product_descriptions ".format(len(descriptions.product_description.unique())))

# %%
(descriptions.product_description.str.count('\d+') + 1).hist(bins=30)
(descriptions.product_description.str.count('\W')+1).hist(bins=30)

# %%
(training_data.product_title.str.count("\\d+") + 1).hist(bins=30)#plot number of digits in title
(training_data.product_title.str.count("\\w+") + 1).hist(bins=30)#plot number of digits in title

# %%
(training_data.search_term.str.count("\\w+") + 1).hist(bins=30) #plot number of words in search therms
(training_data.search_term.str.count("\\d+") + 1).hist(bins=30) #plot number of digits in search terms

# %%
(training_data.relevance ).hist(bins=30)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import norm  

training_data.relevance.plot(kind='hist', normed=True)

mu, std = norm.fit(training_data.relevance)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %%
print('total data has html tags in',descriptions.product_description.str.count('<br$').values.sum())

# %%
descriptions[descriptions.product_description.str.contains("<br")].values.tolist()[:3]

# %%
descriptions.product_description.str.contains("Click here to review our return policy for additional information regarding returns").values.sum()

# %%
training_data[training_data.search_term.str.contains("^\\d+ . \\d+$")].head(10)

# %%
training_data[training_data.product_uid==100030]

# %% [markdown]
# from above the following conclusion follows.
#    - At first there exists fields which has html tags in for __description__ dataset. (maybe and error made by the scrapper) along with _Click here to review our return policy_
#    - There is no missing/empty values in any of these datasets
#    - in dataset __description__ field product_description contains more digits than word characters
#    - some query in dataset __training__ are too straight, it's hard to guess exactly what user meant in terms of broad  sense
#    - some of the search query in dataset __training__ has too specific meaning like 8 4616809045 9
#    - number of diggits appearence in the product title tends to be greater number of characters for dataset __training__ (and the same is true for search query field)
#    - the relevancy score is between 1 and 3. Because the density of product whose relevancy score is between 2 and 3 is higher we can conclude that most of search query has been classifield between 2 and 3
#    - The histogram of relevancy score doesn't follow standard distribution pattern
#
#
#
# In order to continue the analysis we will need the whole datasets
#    - description datasets might be joined together to training by the product_uid (the same holds for attribute datasets) then clean the html parts

# %% [markdown]
# ## Data cleaning

# %%
## let's create first the cleaning functions
from bs4 import BeautifulSoup
import lxml
import re
import nltk
from nltk.corpus import stopwords # Import the stop word list
from nltk.metrics import edit_distance
from string import punctuation
from collections import Counter


def remove_html_tag(text):
    soup = BeautifulSoup(text, 'lxml')
    text = soup.get_text().replace('Click here to review our return policy for additional information regarding returns', '')
    return text

def str_stemmer(doc):
    # split into tokens by white space
    tokens = doc.split()
    # remove punctuation from each token
    table = str.maketrans('', '', punctuation)
    tokens = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) > 1]
    return ' '.join(tokens)

def str_stemmer_title(s):
#     return " ".join([stemmer.stem(word) for word in s.lower().split()])
    return " ".join(map(stemmer.stem, s.lower().split()))

def str_common_word(str1, str2):
    whole_set = set(str1.split())
#     return sum(int(str2.find(word)>=0) for word in whole_set)
    return sum(int(str2.find(word)>=0) for word in whole_set)


def get_shared_words(row_data):
    return np.sum([str_common_word(*row_data[:-1]), str_common_word(*row_data[1:])])

# %%
############### cleaning html tags ##################
has_tag_in = descriptions.product_description.str.contains('<br')
descriptions.loc[has_tag_in, 'product_description'] = descriptions.loc[has_tag_in, 'product_description'].map(lambda x:remove_html_tag(x))
###############

# %% [markdown]
# Examing the search query in the datasets __training__, there some misspelings for field _search_term_ contains a lot of misspelling (more than 3000). This might be fixed by using Google API

# %%
import requests
import re
import time
from random import randint

START_SPELL_CHECK="<span class=\"spell\">Showing results for</span>"
END_SPELL_CHECK="<br><span class=\"spell_orig\">Search instead for"
HTML_Codes = (("'", '&#39;'),('"', '&quot;'),('>', '&gt;'),('<', '&lt;'),('&', '&amp;'))

def spell_check(s):
    q = '+'.join(s.split())
    time.sleep(  randint(0,1) ) #relax and don't let google be angry
    r = requests.get("https://www.google.co.uk/search?q="+q)
    content = r.text
    start=content.find(START_SPELL_CHECK) 
    if ( start > -1 ):
        start = start + len(START_SPELL_CHECK)
        end=content.find(END_SPELL_CHECK)
        search= content[start:end]
        search = re.sub(r'<[^>]+>', '', search)
        for code in HTML_Codes:
            search = search.replace(code[1], code[0])
        search = search[1:]
    else:
        search = s
    return search

# %% [markdown]
# Indeed correcting the misspelings words might help, due to ability of reproducing the result at Kaggle, we won't do spell correction

# %%
training_data = pd.merge(training_data, descriptions, 
                         on="product_uid", how="left")

# %%
print("It has blank/empty fields ",training_data.isnull().values.sum())

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Plan
# We are going to do the following:
# 0. Join dataset __training__ with __description__  by  _product uid_ (already done)
#
# 2. Create num columns based on text columns
#     - count number of words from search query which appears both in product_title and product_description
#     - compute edit distnace from search query which appears both in product_title and product_title
#     - compute the cosine similarity between search query, product_title and product_description
#     - count number of words in the product description
#     - create new columns for each pair
#
# 3. Remove all text columns
#
# As a result we will have vectors of numbers that suites well for the machine learning.

# %%
print("has blank/empty values",training_data.isnull().values.any())

# %%
from nltk.corpus import brown, stopwords
from nltk.cluster.util import cosine_distance
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter


def sentence_similarity(columns,stopwords=None):
    sent1, sent2 = columns[0], columns[1]
    sent1 = sent1.split(' ')
    sent2 = sent2.split(' ')
    if stopwords is None:
        stopwords = []
 
    sent1 = [w.lower() for w in sent1]
    sent2 = [w.lower() for w in sent2]
 
    all_words = list(set(sent1 + sent2))
 
    vector1 = [0] * len(all_words)
    vector2 = [0] * len(all_words)
 
    # build the vector for the first sentence
    for w in sent1:
        if w in stopwords:
            continue
        vector1[all_words.index(w)] += 1
 
    # build the vector for the second sentence
    for w in sent2:
        if w in stopwords:
            continue
        vector2[all_words.index(w)] += 1
 
    return 1 - cosine_distance(vector1, vector2)

def get_jaccard_sim(columns): 
    str1, str2 = columns[0], columns[1]
    a = set(str1.split()) 
    b = set(str2.split())
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))


def calc_edit_dist(row):
    return edit_distance(*row)

# %%
################begin testing
## let's create first the cleaning functions
from bs4 import BeautifulSoup
import lxml
import re
import nltk
from nltk.corpus import stopwords # Import the stop word list
from nltk.metrics import edit_distance
from string import punctuation
from collections import Counter


def remove_html_tag(text):
    soup = BeautifulSoup(text, 'lxml')
    text = soup.get_text().replace('Click here to review our return policy for additional information regarding returns', '')
    return text

def str_stemmer(doc):
    # split into tokens by white space
    tokens = doc.split()
    # remove punctuation from each token
    table = str.maketrans('', '', punctuation)
    tokens = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) > 1]
    return ' '.join(tokens)


def str_stemmer_tokens(tokens):
    # split into tokens by white space
#     tokens = doc.split()
    # remove punctuation from each token
    table = str.maketrans('', '', punctuation)
    tokens = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) > 1]
    return ' '.join(tokens)

def str_stemmer_title(s):
    return " ".join(map(stemmer.stem, s))

def str_common_word(str1, str2):
    whole_set = set(str1.split())
#     return sum(int(str2.find(word)>=0) for word in whole_set)
    return sum(int(str2.find(word)>=0) for word in whole_set)


# def str_common_word(str1, str2):
#     return sum(int(str2.find(word)>=0) for word in str1.split())


def str_common_word2(str1, str2):
    part_of_first = set(str1)
    return sum(1 for word in str2 if word in part_of_first)
#     return sum(int(str2.find(word)>=0) for word in str1.split())

def get_shared_words_mut(row_data):
    return np.sum([str_common_word2(*row_data[:-1]), str_common_word2(*row_data[1:])])


def get_shared_words_imut(row_data):
    return np.sum([str_common_word(*row_data[:-1]), str_common_word2(*row_data[1:])])
    
from nltk.corpus import brown, stopwords
from nltk.cluster.util import cosine_distance
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter


def sentence_similarity(columns,stopwords=None):
    sent1, sent2 = columns[0], columns[1]
    if stopwords is None:
        stopwords = []
 
    sent1 = [w.lower() for w in sent1]
    sent2 = [w.lower() for w in sent2]
 
    all_words = list(set(sent1 + sent2))
 
    vector1 = [0] * len(all_words)
    vector2 = [0] * len(all_words)
 
    # build the vector for the first sentence
    for w in sent1:
        if w in stopwords:
            continue
        vector1[all_words.index(w)] += 1
 
    # build the vector for the second sentence
    for w in sent2:
        if w in stopwords:
            continue
        vector2[all_words.index(w)] += 1
 
    return 1 - cosine_distance(vector1, vector2)

def get_jaccard_sim(columns): 
    str1, str2 = columns[0], columns[1]
    a = set(str1) 
    b = set(str2)
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

# %%
############## apply stemming #####################
#  also .apply(, raw=True) might be a good options
# https://github.com/s-heisler/pycon2017-optimizing-pandas to see why it is done on this way
############## apply stemming #####################
# training_data['search_term'] = list(map(str_stemmer_title,training_data['search_term'].values))
# training_data['product_title'] = list(map(str_stemmer, training_data['product_title'].values))
# training_data['product_description'] = list(map(str_stemmer, training_data['product_description'].values))

# training_data['shared_words'] = list(map(get_shared_words, training_data[['search_term','product_description', 'product_title']].values))

# training_data["edistance_sprot"] = list(map(calc_edit_dist, training_data[["search_term","product_title"]].values))
# training_data["edistance_sd"] = list(map(calc_edit_dist, training_data[["search_term","product_description"]].values))


# training_data['cos_dis_sqt'] = list(map(sentence_similarity ,training_data[["search_term","product_title"]].values))
# training_data['cos_dis_sqd'] = list(map(sentence_similarity, training_data[["search_term","product_description"]].values))


# training_data['j_dis_sqt'] = list(map(get_jaccard_sim, training_data[["search_term","product_title"]].values))
# training_data['j_dis_sqd'] = list(map(get_jaccard_sim, training_data[["search_term","product_description"]].values))

# training_data['j_dis_sqt'] = list(map(get_jaccard_sim, training_data[["search_term","product_title"]].values))
# training_data['j_dis_sqd'] = list(map(get_jaccard_sim, training_data[["search_term","product_description"]].values))

# training_data['search_query_length'] = training_data.search_term.str.len()
# training_data['number_of_words_in_descr'] = training_data.product_description.str.count("\\w+")



training_data['search_term_tokens'] = training_data.search_term.str.lower().str.split()
training_data['product_title_tokens'] = training_data.product_title.str.lower().str.split()
training_data['product_description_tokens'] = training_data.product_description.str.lower().str.split()

training_data['search_term'] = [str_stemmer_title(_) for _ in training_data.search_term_tokens.values.tolist()]
training_data['product_title'] = [str_stemmer_tokens(_) for _ in training_data.product_title_tokens.values.tolist()]
training_data['product_description'] = [str_stemmer_tokens(_) for _ in training_data.product_description_tokens.values.tolist()]


training_data['shared_words_mut'] = [get_shared_words_mut(columns)
                         for columns in 
                         training_data[['search_term_tokens', 'product_title_tokens', 'product_description_tokens']].values.tolist()
                        ]

training_data['shared_words'] = list(map(get_shared_words_imut, training_data[['search_term','product_description', 'product_title']].values))



training_data["edistance_sprot"] = [edit_distance(word1, word2) for word1, word2 in
                                    training_data[["search_term","product_title"]].values.tolist()]


training_data["edistance_sd"] = [edit_distance(word1, word2) for word1, word2 in
                                    training_data[["search_term","product_description"]].values.tolist()]

training_data['j_dis_sqt'] = [get_jaccard_sim(rows) for rows in training_data[["search_term_tokens","product_title_tokens"]].values]
training_data['j_dis_sqd'] = [get_jaccard_sim(rows) for rows in training_data[["search_term_tokens","product_description_tokens"]].values]

training_data['search_query_length'] = training_data.search_term.str.len()
training_data['number_of_words_in_descr'] = training_data.product_description.str.count("\\w+")


training_data['cos_dis_sqt'] = [ sentence_similarity(rows) for rows in training_data[["search_term","product_title"]].values]
training_data['cos_dis_sqd'] = [sentence_similarity(rows) for rows in training_data[["search_term","product_description"]].values]

# %%
# training_data.corr()
training_data.head(3)

# %% [markdown]
# __test dataset__
# we have to have to apply symmetric transformation for both data set, except relevance score field since it is target field. Except we are not allow to take any actions which might lead to overfitting the data

# %%
testing_data = pd.merge(testing_data, descriptions, 
                         on="product_uid", how="left")
print("has blank/empty values",testing_data.isnull().values.any())

# %%
############## apply stemming for test data #####################
# testing_data['search_term'] = list(map(str_stemmer_title, testing_data['search_term'].values))
# testing_data['product_title'] = list(map(str_stemmer, testing_data['product_title'].values))
# testing_data['product_description'] = list(map(str_stemmer, testing_data['product_description'].values))
testing_data['search_term_tokens'] = testing_data.search_term.str.lower().str.split()
testing_data['product_title_tokens'] = testing_data.product_title.str.lower().str.split()
testing_data['product_description_tokens'] = testing_data.product_description.str.lower().str.split()

testing_data['search_term'] = [str_stemmer_title(_) for _ in testing_data.search_term_tokens.values.tolist()]
testing_data['product_title'] = [str_stemmer_tokens(_) for _ in testing_data.product_title_tokens.values.tolist()]
testing_data['product_description'] = [str_stemmer_tokens(_) for _ in testing_data.product_description_tokens.values.tolist()]

############## end stemming #####################

# %%
############## building custome feature for test data, let's build a few of them before compare which one is the best ###########
# testing_data['shared_words'] = list(map(get_shared_words, testing_data[['search_term','product_description', 'product_title']].values))
# testing_data["edistance_sprot"] = list(map(calc_edit_dist, testing_data[["search_term","product_title"]].values))
# testing_data["edistance_sd"] = list(map(calc_edit_dist, testing_data[["search_term","product_description"]].values))


# testing_data['cos_dis_sqt'] = list(map(sentence_similarity ,testing_data[["search_term","product_title"]].values))
# testing_data['cos_dis_sqd'] = list(map(sentence_similarity, testing_data[["search_term","product_description"]].values))



# testing_data['j_dis_sqt'] = list(map(get_jaccard_sim, testing_data[["search_term","product_title"]].values))
# testing_data['j_dis_sqd'] = list(map(get_jaccard_sim, testing_data[["search_term","product_description"]].values))

# testing_data['j_dis_sqt'] = list(map(get_jaccard_sim, testing_data[["search_term","product_title"]].values))
# testing_data['j_dis_sqd'] = list(map(get_jaccard_sim, testing_data[["search_term","product_description"]].values))

# testing_data['search_query_length'] = testing_data.search_term.str.len()
# testing_data['number_of_words_in_descr'] = testing_data.product_description.str.count("\\w+")

testing_data['shared_words_mut'] = [get_shared_words_mut(columns)
                         for columns in 
                         testing_data[['search_term_tokens', 'product_title_tokens', 'product_description_tokens']].values.tolist()
                        ]

testing_data['shared_words'] = list(map(get_shared_words_imut, testing_data[['search_term','product_description', 'product_title']].values))



testing_data["edistance_sprot"] = [edit_distance(word1, word2) for word1, word2 in
                                    testing_data[["search_term","product_title"]].values.tolist()]


testing_data["edistance_sd"] = [edit_distance(word1, word2) for word1, word2 in
                                    testing_data[["search_term","product_description"]].values.tolist()]

testing_data['j_dis_sqt'] = [get_jaccard_sim(rows) for rows in testing_data[["search_term_tokens","product_title_tokens"]].values]
testing_data['j_dis_sqd'] = [get_jaccard_sim(rows) for rows in testing_data[["search_term_tokens","product_description_tokens"]].values]

testing_data['search_query_length'] = testing_data.search_term.str.len()
testing_data['number_of_words_in_descr'] = testing_data.product_description.str.count("\\w+")


testing_data['cos_dis_sqt'] = [ sentence_similarity(rows) for rows in testing_data[["search_term","product_title"]].values]
testing_data['cos_dis_sqd'] = [sentence_similarity(rows) for rows in testing_data[["search_term","product_description"]].values]

# %%
testing_data.corr()

# %%
training_data.describe()

# %%
testing_data.describe()

# %%
import seaborn as sns
plt.figure(figsize=(12, 12))
temp = training_data.drop(['product_uid','id'],axis=1)
sns.heatmap(temp.corr(), annot=True)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(12, 12))
temp = testing_data.drop(['product_uid','id'],axis=1)
sns.heatmap(temp.corr(), annot=True)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import norm  

training_data.cos_dis_sqd.plot(kind='hist', normed=True)

mu, std = norm.fit(training_data.cos_dis_sqd)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %% [markdown]
# let's check wheather this is follows Gaussian distribution or not. Indeed it doesn't follow Gaussian distribution, that follows from Shapiro test

# %%
from statsmodels.graphics.gofplots import qqplot
from scipy.stats import shapiro


from matplotlib import pyplot
qqplot(training_data.cos_dis_sqd, line='s')
pyplot.show()

stat, p = shapiro(training_data.cos_dis_sqd)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# %% [markdown]
# let's try to find out if wheather it follows normal distribution or not, by doing a few others test

# %%
from scipy.stats import normaltest

stat, p = normaltest(training_data.cos_dis_sqd)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')

# %%
from scipy.stats import anderson

result = anderson(training_data.cos_dis_sqd)
print('Statistic: %.3f' % result.statistic)
p = 0
for i in range(len(result.critical_values)):
    sl, cv = result.significance_level[i], result.critical_values[i]
    if result.statistic < result.critical_values[i]:
        print('%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
    else:
        print('%.3f: %.3f, data does not look normal (reject H0)' % (sl, cv))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import norm  

training_data.cos_dis_sqt.plot(kind='hist', normed=True)

mu, std = norm.fit(training_data.cos_dis_sqt)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %%
from matplotlib import pyplot
qqplot(training_data.cos_dis_sqt, line='s')
pyplot.show()

stat, p = shapiro(training_data.cos_dis_sqt)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# %% [markdown]
# From the below histogram we can conclude that the sum of shared words between search_query product_title, and product description follows the standard distribution.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import norm  

training_data.shared_words.plot(kind='hist', normed=True)

mu, std = norm.fit(training_data.shared_words)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %%
from statsmodels.graphics.gofplots import qqplot
from scipy.stats import shapiro


from matplotlib import pyplot
qqplot(training_data.shared_words, line='s')
pyplot.show()

stat, p = shapiro(training_data.shared_words)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import norm  

training_data.edistance_sprot.plot(kind='hist', normed=True)

mu, std = norm.fit(training_data.edistance_sprot)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import norm  

training_data.search_query_length.plot(kind='hist', normed=True)

mu, std = norm.fit(training_data.search_query_length)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %% [markdown]
# let's examing if the same behaviour can be spotted on __testing__ dataset

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import norm  

testing_data.cos_dis_sqd.plot(kind='hist', normed=True)

mu, std = norm.fit(testing_data.cos_dis_sqd)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import norm  

testing_data.cos_dis_sqt.plot(kind='hist', normed=True)

mu, std = norm.fit(testing_data.cos_dis_sqt)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import norm  

testing_data.shared_words.plot(kind='hist', normed=True)

mu, std = norm.fit(testing_data.shared_words)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import norm  

testing_data.edistance_sprot.plot(kind='hist', normed=True)

mu, std = norm.fit(testing_data.edistance_sprot)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import norm  

testing_data.search_query_length.plot(kind='hist', normed=True)

mu, std = norm.fit(testing_data.search_query_length)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %%
sns.pairplot(training_data)

# %%
sns.pairplot(testing_dataing_data)

# %% [markdown]
# # 3. Let's start machine learning
# first of all let's create training and test data sets

# %% [markdown]
# We are going to apply the following models:
# 1. RandomForestRegressor
# 2. LinearRegression
# 4. GradientBoostingRegressor
# 5. BaggingRegressor
# 6. Chain model withing pipeline
# 7. XGBoost
# 8. CatBoost
# 9. Naive Baies
# 10. PolynomialFeatures for all previous algorithms
#
#
# ### Plan
# We are going to do the following:
# 0. Define pipeline
# 1. drop non numeric columns because these information has been already transformed to numberic
# 2. Apply the model which has been mentioned above within pipeline mode and outside pipeline
# 3. Train models and compare their result on __test__ dataset
# 4. write a summary about it

# %%
df_training = training_data.drop(['product_title','search_term','product_description', 'product_title_tokens', 'product_description_tokens','product_title_tokens','search_term_tokens'],axis=1)

y_train = df_training['relevance'].values
X_train = df_training.drop(['id','relevance'],axis=1).values

# %%
df_training.head(3)

# %%
# X_test = testing_data.drop(['id','product_title','search_term','product_description'],axis=1).values
X_test = testing_data.drop(['id','product_title','search_term','product_description', 'product_title_tokens', 'product_description_tokens','product_title_tokens','search_term_tokens'],axis=1).values

id_test = testing_data['id']

# %% [markdown]
# ## 3.1 RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators = 3, n_jobs = -1, random_state = 17, verbose = 1)
rfr.fit(X_train, y_train)

y_pred = rfr.predict(X_test)

pd.DataFrame({"id": id_test, "relevance": y_pred}).to_csv('submission.csv',index=False)

# %% [markdown]
# ## 3.2 LinearRegression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression(n_jobs = -1)
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# pd.DataFrame({"id": id_test, "relevance": y_pred}).to_csv('submission.csv',index=False)

# %% [markdown]
# ## 3.3 GradientBoostingRegressor

# %%
import sklearn
from sklearn.ensemble import GradientBoostingRegressor

param_grid = {
                'loss' : ['ls'],
                'n_estimators' : [3], 
                'max_depth' : [9],
                'max_features' : ['auto'] 
             }

gbr = GradientBoostingRegressor()

model_gbr = sklearn.model_selection.GridSearchCV(estimator = gbr, n_jobs = -1, param_grid = param_grid)
model_gbr.fit(X_train, y_train)

y_pred = model_gbr.predict(X_test)

# pd.DataFrame({"id": id_test, "relevance": y_pred}).to_csv('submission.csv',index=False)

# %% [markdown]
# ## 3.4 BaggingRegressor based on  RandomForestRegressor

# %%
from sklearn.ensemble import BaggingRegressor
rf = RandomForestRegressor(max_depth = 20, max_features =  'sqrt', n_estimators = 3)
clf = BaggingRegressor(rf, n_estimators=3, max_samples=0.1, random_state=25)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

# pd.DataFrame({"id": id_test, "relevance": y_pred}).to_csv('submission.csv',index=False)

# %% [markdown]
# ## 3.5 Chain model withing pipeline

# %%
# define models which will be chained togher in a bigger model, which aims to predict the relevancy score
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold

#define standard scaler
scaler = StandardScaler()
scaler.fit(X_train, y_train)
scaled_train_data = scaler.transform(X_train)
scaled_test_data = scaler.transform(X_test)


rf = RandomForestRegressor(n_estimators=4, max_depth=6, random_state=0)
clf = BaggingRegressor(rf, n_estimators=4, max_samples=0.1, random_state=25)


pipeline = Pipeline(steps = [('scaling', scaler), ('baggingregressor', clf)])
#end pipeline 
pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)

pd.DataFrame({"id": id_test, "relevance": y_pred}).to_csv('submission.csv',index=False)

# %% [markdown]
# ## 3.6 Naive Bayes

# %%
from sklearn.linear_model import BayesianRidge

gnb = BayesianRidge()
param_grid = {}
model_nb = sklearn.model_selection.GridSearchCV(estimator = gnb, param_grid = param_grid, n_jobs = -1)
model_nb.fit(X_train, y_train)

y_pred = model_nb.predict(X_test)
# pd.DataFrame({"id": id_test, "relevance": y_pred}).to_csv('submission.csv',index=False)

# %% [markdown]
# ## 3.7 XGBoost

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor()
param_grid = {'max_depth':[5, 6], 
              'n_estimators': [130, 150, 170], 
              'learning_rate' : [0.1]}
model_xgb = sklearn.model_selection.GridSearchCV(estimator = xgb, param_grid = param_grid, n_jobs = -1)
model_xgb.fit(X_train, y_train)

y_pred = model_xgb.predict(X_test)
# pd.DataFrame({"id": id_test, "relevance": y_pred}).to_csv('submission.csv',index=False)

# %% [markdown]
# # Results

# %% [markdown]
# |Regressor|Train|Kaggle
# |:----------------------|----------|----------|
# |CatBoostRegressor|-|-|
# |XGBRegressor|-|-|
# |GradientBoostingRegressor|-|-|
# |PolynomialFeatures on GradientBoostingRegressor|-|-|
# |PolynomialFeatures on XGBRegressor|-|-|
# |PolynomialFeatures on LinearRegression|-|-|
# |PolynomialFeatures on BaggingRegressor on RandomForestRegressor|-|-|
# |BaggingRegressor on RandomForestRegressor|0.53480|0.53427|
# |Chaining toghether using Pipeline|0.53063|0.53100|
# |BayesianRidge|-|-|
# |LinearRegression|-|-|
# |PolynomialFeatures on BayesianRidge|-|-|
# |RandomForestRegressor|0.59063|0.58869|
