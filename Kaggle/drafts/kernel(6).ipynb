# %% [markdown]
# ## Data Cleaning and Shape Examining

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer('english')

training_data = pd.read_csv("input/train.csv.zip", encoding="ISO-8859-1")
testing_data = pd.read_csv("input/test.csv.zip", encoding="ISO-8859-1")
attribute_data = pd.read_csv('input/attributes.csv.zip')
descriptions = pd.read_csv('input/product_descriptions.csv.zip')

training_data = pd.merge(training_data, descriptions, 
                         on="product_uid", how="left")

# %%
import spacy
nlp = spacy.load('en')

# %%
training_data['length_search_terms'] = training_data.search_term.str.len()

# %%
training_data
# Out:
#            id  product_uid                                      product_title  \
# 0           2       100001                  Simpson Strong-Tie 12-Gauge Angle
# 1           3       100001                  Simpson Strong-Tie 12-Gauge Angle
# 2           9       100002  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3          16       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4          17       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 5          18       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 6          20       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 7          21       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 8          23       100007  Lithonia Lighting Quantum 2-Light Black LED Em...
# 9          27       100009  House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...
# 10         34       100010       Valley View Industries Metal Stakes (4-Pack)
# 11         35       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 12         37       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 13         38       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 14         48       100012  Hampton Bay Caramel Simple Weave Bamboo Rollup...
# 15         51       100013  InSinkErator SinkTop Switch Single Outlet for ...
# 16         65       100016  Sunjoy Calais 8 ft. x 5 ft. x 8 ft. Steel Tile...
# 17         69       100017  MD Building Products 36 in. x 36 in. Cloverlea...
# 18         75       100017  MD Building Products 36 in. x 36 in. Cloverlea...
# 19         81       100017  MD Building Products 36 in. x 36 in. Cloverlea...
# 20         85       100017  MD Building Products 36 in. x 36 in. Cloverlea...
# 21         88       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 22         90       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 23         92       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 24        101       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 25        105       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 26        106       100019  House of Fara 8 Linear ft. MDF Overlapping Wai...
# 27        113       100021  1804 Dual Spray Half Pattern 4 in Pop-Up Spray...
# 28        114       100021  1804 Dual Spray Half Pattern 4 in Pop-Up Spray...
# 29        117       100022  Samsung 4.2 cu. ft. Front Load Washer with Ste...
# ...       ...          ...                                                ...
# 74037  221398       206588  Cake Boss Decorating Tools 3-Piece Plastic Ici...
# 74038  221400       206589  Husky Universal Pass-Through Mechanics Tool Se...
# 74039  221401       206590    Crosley LaFayette Low Profile TV Stand in Black
# 74040  221404       206593  Rust-Oleum Automotive 8 oz. Special White Auto...
# 74041  221405       206594  Foremost Tides 33 in. to 35 in. x 65 in. Frame...
# 74042  221407       206596  Bali Cut-to-Size Crown 3.5 in. PVC Louver Set ...
# 74043  221408       206597  Home Fashion Technologies 14 in. x 59 in. Soli...
# 74044  221409       206598              Newport Coastal Photo Eye Replacement
# 74045  221411       206599  HYDRONIX 12 in. x 2-1/2 in. Inline Coconut Car...
# 74046  221412       206600  Worx 12 in. Ni-cd 24-Volt 3-5 Hour Charger Gra...
# 74047  221413       206601  3M Tekk Protection White Vented Hard Hat with ...
# 74048  221415       206602  Hy-Lite Glass Block Fixed Vinyl Windows Driftw...
# 74049  221416       206603  Westinghouse 3 ft. Oil Rubbed Bronze Beaded Ch...
# 74050  221419       206606  BEHR Premium Plus #ICC-101 Florentine Clay Zer...
# 74051  221420       206607  Home Legend Palace Oak Light 3/4 in. Thick x 3...
# 74052  221422       206609  Whitehaus Collection Isabella Wall-Mounted Bat...
# 74053  221423       206610  Champion Power Equipment 6.5 HP Gas-Powered 3 ...
# 74054  221426       206613                    Everbilt 4 in. White Wall Guard
# 74055  221427       206614  Daltile Villa Valleta Calais Springs 18 in. x ...
# 74056  221432       206619  Home Styles Stone Harbor 51 in. Round 7-Piece ...
# 74057  221434       206621  Crown Bolt M6-32 x 90 mm. Internal Hex Socket ...
# 74058  221443       206627           25 in. Stainless Tip-Out Sink Front Tray
# 74059  221449       206631  Masonite New Haven Three Quarter Oval Lite Pri...
# 74060  221450       206632  Lilly Miller UltraGreen 1 Gal. Vitamin B-1 Pla...
# 74061  221455       206637  Schluter Rondec Stainless Steel 3/8 in. x 1 in...
# 74062  221457       206638  Atlantic Windowpane 576 CD or 192 DVD Blu-Ray ...
# 74063  221458       206639  Philips 40-Watt Halogen R20 Flood Light Bulb (...
# 74064  221463       206641  Schlage Camelot In-Active Aged Bronze Handlese...
# 74065  221471       206648  Plastec 11 in. x 24 in. Rose Garden Wall Decor...
# 74066  221473       206650  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
#
#                                       search_term  relevance  \
# 0                                   angle bracket       3.00
# 1                                       l bracket       2.50
# 2                                       deck over       3.00
# 3                                rain shower head       2.33
# 4                              shower only faucet       2.67
# 5                                  convection otr       3.00
# 6                            microwave over stove       2.67
# 7                                      microwaves       3.00
# 8                                 emergency light       2.67
# 9                                         mdf 3/4       3.00
# 10                                   steele stake       2.67
# 11                 briggs and stratton lawn mower       3.00
# 12                                       gas mowe       3.00
# 13                                    honda mower       2.00
# 14             hampton bay chestnut pull up shade       2.67
# 15                                       disposer       2.67
# 16                                   grill gazebo       3.00
# 17                                    door guards       1.00
# 18                         metal plate cover gcfi       1.67
# 19                                 radiator grate       2.33
# 20                                windows screens       2.33
# 21                       1x1 rail decorative wood       1.33
# 22                         4*8 beadboard paneling       2.67
# 23                               4x8wood paneling       2.33
# 24                                        MDF 4x8       1.33
# 25                            wainscot chair rail       2.33
# 26                        wainscot plank paneling       2.33
# 27                                 lawn sprkinler       2.00
# 28                             rainbird sprinkler       2.33
# 29                           PLATFORM FOR WASHERS       2.67
# ...                                           ...        ...
# 74037                plastic 3 piece nativity set       1.67
# 74038                  pass through curtain rings       1.33
# 74039                crosley lafayette kf30024bwh       2.33
# 74040                            dremel auto rust       2.33
# 74041                   privacy glass pivot doors       2.67
# 74042                alabaster blinds 39x72 alvin       1.67
# 74043       exterior shutter with movable louvers       3.00
# 74044                                 lightsensor       2.67
# 74045                      bypass 12 water filter       1.33
# 74046                                     ni-2.4v       2.00
# 74047                        hard hat with mining       1.67
# 74048    replace a broken glass in a vinyl window       2.00
# 74049                 ceiling fan with chain cord       1.00
# 74050                             florentine clay       2.33
# 74051                          trim a home lights       2.00
# 74052                     whitehaus bathroom sinl       2.33
# 74053                        6.5 hp gas generator       2.33
# 74054                      splash guard for  wall       2.00
# 74055                spicewood springs floor tile       1.67
# 74056                        laguna porcelin tile       2.00
# 74057                               m6 screw 90mm       2.67
# 74058                           sink tip-out tray       3.00
# 74059          fiberglass front doors by masonite       3.00
# 74060                          starter fertillzer       2.00
# 74061  rondec stainless steel 3/8 edge protection       3.00
# 74062                              tv riser glass       1.00
# 74063                           r20 halogen light       3.00
# 74064     schlage lock siena half dummy knob with       2.33
# 74065                           zen garden  decor       3.00
# 74066                fine sheer curtain 63 inches       2.33
#
#                                      product_description  length_search_terms
# 0      Not only do angles make joints stronger, they ...                   13
# 1      Not only do angles make joints stronger, they ...                    9
# 2      BEHR Premium Textured DECKOVER is an innovativ...                    9
# 3      Update your bathroom with the Delta Vero Singl...                   16
# 4      Update your bathroom with the Delta Vero Singl...                   18
# 5      Achieving delicious results is almost effortle...                   14
# 6      Achieving delicious results is almost effortle...                   20
# 7      Achieving delicious results is almost effortle...                   10
# 8      The Quantum Adjustable 2-Light LED Black Emerg...                   15
# 9      Get the House of Fara 3/4 in. x 3 in. x 8 ft. ...                    7
# 10     Valley View Industries Metal Stakes (4-Pack) a...                   12
# 11     Recycler 22 in. Personal Pace Variable Speed S...                   30
# 12     Recycler 22 in. Personal Pace Variable Speed S...                    8
# 13     Recycler 22 in. Personal Pace Variable Speed S...                   11
# 14     The 96 in. wide Caramel Simple Weave Rollup Ba...                   34
# 15     The InSinkErator SinkTop Switch Single Outlet ...                    8
# 16     Make grilling great with this handsome and fun...                   12
# 17     The MD Building Products 36 in. x 36 in. x 1/5...                   11
# 18     The MD Building Products 36 in. x 36 in. x 1/5...                   22
# 19     The MD Building Products 36 in. x 36 in. x 1/5...                   14
# 20     The MD Building Products 36 in. x 36 in. x 1/5...                   15
# 21     The House of Fara 8 Linear ft. primed MDF Over...                   24
# 22     The House of Fara 8 Linear ft. primed MDF Over...                   22
# 23     The House of Fara 8 Linear ft. primed MDF Over...                   16
# 24     The House of Fara 8 Linear ft. primed MDF Over...                    7
# 25     The House of Fara 8 Linear ft. primed MDF Over...                   19
# 26     The House of Fara 8 Linear ft. primed MDF Over...                   23
# 27     Installed in parks and backyards across the gl...                   14
# 28     Installed in parks and backyards across the gl...                   18
# 29     The Samsung 4.2 cu. ft. Front Load Washer with...                   20
# ...                                                  ...                  ...
# 74037  Have the perfect trio of decorating bags with ...                   28
# 74038  The Husky 126-Piece Pass-Through Socket and Ra...                   26
# 74039  Enhance your living space with Crosley's impec...                   28
# 74040  Rust-Oleum Automotive Touch-Up aerosols are id...                   16
# 74041  Whether you are designing a new bathroom, or r...                   25
# 74042  Bali Cut-to-Size Vertical Blinds offer beautif...                   28
# 74043  Instantly add value and style to your home wit...                   37
# 74044  This Newport Coastal Photo Eye Replacement con...                   11
# 74045  If you already have an inline filter and want ...                   22
# 74046  Flexibility at its best. The Worx 2-in-1 12 Gr...                    7
# 74047  3M TEKK Protection Vented Pro Ratchet Hard Hat...                   20
# 74048  Excellent privacy and decorative solution for ...                   40
# 74049  This Westinghouse Lighting Oil Rubbed Bronze B...                   27
# 74050  BEHR Premium Plus Zero VOC, Self-Priming Inter...                   15
# 74051  Quarter round is typically placed in front of ...                   18
# 74052  Beautify your bathroom or powder room with a W...                   23
# 74053  The Champion Power Equipment 3 in. semi-trash ...                   20
# 74054  The Everbilt 4 in. Wall Guard helps prevent da...                   22
# 74055  This dal-tile villa valleta calais springs por...                   28
# 74056  Stone Harbor 7-Piece Dining Set includes Large...                   20
# 74057  Crown Bolt's metric socket cap screws are idea...                   13
# 74058  Add a little luxury to otherwise wasted space ...                   17
# 74059  Create an inviting, stylish entryway with the ...                   34
# 74060  Lilly Miller UltraGreen Vitamin B-1 Plant Star...                   18
# 74061  The EV/RO100E is a prefabricated corner for Ro...                   42
# 74062  Atlantic, Inc. 94835722 Uniquely designed for ...                   14
# 74063  Philips Energy Advantage lamps use less energy...                   17
# 74064  The Schlage Camelot In-Active Aged Bronze Hand...                   39
# 74065  The Rose Garden is inspired by the popular ear...                   17
# 74066  No. 918 Millennial Ryan heathered texture semi...                   28
#
# [74067 rows x 7 columns]

# %% [markdown]
# As in the dataset page has mentioned that it might contains some embedded html tags, let's plot and see how many in percentage, more prececily the fields 'product_description'

# %%
# %matplotlib inline
total_length = len(descriptions['product_description'] )
has_tag = sum([1 for _ in descriptions['product_description'] if '<br' in _])
no_tags = total_length - has_tag

import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.hist(x=[has_tag])
ax.ticklabel_format(useOffset=False)
_ = plt.xlabel('number of phrase which has html tags in')

plt.show()
print('has html tags in ',has_tag)
print('doesn\'t have html tags in ', no_tags)

# %% [markdown]
# Now let's see what is the frequency of search query which include digits in it with respect to product_title which
# includes words. As you can see most of them includes digits in search bar.

# %%
(training_data.search_term.str.count("\\w+") + 1).hist(bins=30) #plot number of words in search therms
(training_data.search_term.str.count("\\d+") + 1).hist(bins=30) #plot number of digits in search terms
# (training_data.product_title.str.count("\\d+") + 1).hist(bins=30)#plot number of digits in title

# %%
(training_data.product_title.str.count("\\w+") + 1).hist(bins=30)#plot number of words in title
(training_data.search_term.str.count("\\w+") + 1).hist(bins=30) #plot number of words in search query

# %%
(training_data.product_title.str.count("\\d+") + 1).hist(bins=30)#plot number of words in title
(training_data.search_term.str.count("\\d+") + 1).hist(bins=30) #plot number of words in search query

# %%
(training_data.product_description.str.count("\\d+") + 1).hist(bins=30)
(training_data.product_description.str.count("\\d+\W+\d+") + 1).hist(bins=30)

# %% [markdown]
# let's plot at histogram following number of words in search query, and on the other hand relevancy score

# %%
(training_data.search_term.str.count("\\w+") + 1).hist(bins=30)
(training_data.relevance + 1).hist(bins=30)

# %% [markdown]
# let's take a look how does the persistence of digits in the search query influence the relevancy score, from below plot it clearly that most of the search query must have between 2.0 and 3.0

# %%
(training_data.search_term.str.count("\\d+")).hist(bins=30)
(training_data.relevance ).hist(bins=30)

# %% [markdown]
# let’s assume that there are zero response for null query search term

# %%
training_data[training_data.search_term.str.count('\\w+') < 1]
# training_data[training_data.search_term.str.contains('^\d+') < 1]

# %%
# an interest case can be see below, unfortunattly we cannot get rid of this element since it will make a bad impact on model
training_data[training_data.product_uid==100030]

# %%
training_data[training_data.product_description.str.contains('.* x .*')].head(4) # at first it looks like nothing unsual

# %% [markdown]
# Unfortunately, it is kind ambiguous to figure out the meaning of digits in the search context like an example below, it can mean anything. we should take care of this when cleaning context. It looks that most of the case the meaning of X is denoted the unit of measure like fit/inch/or something by something

# %%
# training_data[training_data.search_term.str.contains("^\\d+ . \\d+$")].head(4)
training_data[(training_data.search_term.str.contains("^\\d+ . \\d+$") )& (training_data.relevance > 2)].head(4)

# %%
# exception_number = training_data[training_data.search_term.str.contains("^\\d+ . \\d+$") ]['search_term'].values
# training_data['test'] = training_data[training_data.search_term.str.contains("^\\d+ . \\d+$") ]['search_term'].str.split(' ').values
# training_data[['product_title', 'product_description', 'relevance', ]].corr()
training_data.head(10)

# %% [markdown]
# In order to apply any standard method for analysis we have to standardize metric for text fields, which we define as follows
#
# - split into tokens by white space
# - remove punctuation from each token
# - remove remaining tokens that are not alphabetic
# - filter out stop words
# - filter out short tokens
#
# and lets also create new feature in the same time which will denote our hypothesis.
#
# \begin{equation*}
# H_1 = \{\ \frac{ card(search query)}{ card(product title)} = high\ relevance\ score\} \\
# H_2 = \{ length(search query)\ influence\ relevance\ score \} \\
# H_3 = \{ card(common\_words(search\ query,product\ title,product\ description)) = influence\ relevance\ score \} \\
# \end{equation*}

# %%
from bs4 import BeautifulSoup
import lxml
import re
import nltk
from nltk.corpus import stopwords # Import the stop word list
from nltk.metrics import edit_distance
from string import punctuation
from collections import Counter
import nltk



def remove_html_tag(text):
    soup = BeautifulSoup(text, 'lxml')
    text = soup.get_text().replace('Click here to review our return policy for additional information regarding returns', '')
    return text

def str_stemmer(doc):
    # split into tokens by white space
    tokens = doc.split()
    # remove punctuation from each token
    table = str.maketrans('', '', punctuation)
    tokens = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) > 1]
    return ' '.join(tokens)

def str_stemmer_title(s):
    return " ".join([stemmer.stem(word) for word in s.lower().split()])

def str_common_word(str1, str2):
    whole_set = set(str1.split())
    return sum(int(str2.find(word)>=0) for word in whole_set)

# %% [markdown]
# Now let's build feature accordingly to
# \begin{equation*}
# H_1, H_2, H_3\\
# \end{equation*}

# %%
num_train = training_data.shape[0]
############### cleaning html tags ##################
has_tag_in = training_data.product_description.str.contains('<br')
training_data.loc[has_tag_in, 'product_description'] = training_data.loc[has_tag_in, 'product_description'].map(lambda x:remove_html_tag(x))
###############

############## apply stemming #####################
training_data['search_term'] = training_data['search_term'].map(lambda x:str_stemmer_title(x))
training_data['product_title'] = training_data['product_title'].map(lambda x:str_stemmer(x))

training_data['product_description'] = training_data['product_description'].map(lambda x:str_stemmer(x))
############## end stemming #####################

############## building custome feature, let's build a few of them before compare which one is the best ###########
training_data['len_of_query'] = training_data['search_term'].map(lambda x:len(x.split())).astype(np.int64)
training_data['shared_words'] = training_data[['search_term','product_description', 'product_title']].apply(lambda row:sum([str_common_word(*row[:-1]), str_common_word(*row[1:])]), axis=1)

# training_data['frequency_digits_in_sq']=training_data.product_description.str.count("\\d+")
training_data['frequency_words_in_sq'] = training_data.product_description.str.count("\\w+")
training_data["distance"] = training_data.loc[:, ["search_term","product_title"]].apply(lambda x: edit_distance(*x), axis=1)

# %%
#let's take a look if there is not empty search query now
# empty_search_query = training_data[training_data.search_term.str.count('\\w+') < 1].values
# print('data frame of empty seach query along with products',empty_search_query)
# # training_data[training_data.product_uid==100030]
# is_anything_none = training_data.isnull().values.any()
# print('presence of Nan values',  is_anything_none)

# training_data['H_1'] = training_data.loc[:, ["product_title","search_term"]].apply(lambda x: len(x[1])/len(x[0]), axis=1)

# training_data
training_data.corr()
# Out:
#                              id  product_uid  relevance  len_of_query  \
# id                     1.000000     0.986738  -0.116426      0.192900
# product_uid            0.986738     1.000000  -0.130656      0.206109
# relevance             -0.116426    -0.130656   1.000000     -0.072279
# len_of_query           0.192900     0.206109  -0.072279      1.000000
# shared_words          -0.036805    -0.033058   0.054164      0.221767
# frequency_words_in_sq -0.067528    -0.062033   0.040146      0.063501
# distance               0.044136     0.045716  -0.034573      0.017572
#
#                        shared_words  frequency_words_in_sq  distance
# id                        -0.036805              -0.067528  0.044136
# product_uid               -0.033058              -0.062033  0.045716
# relevance                  0.054164               0.040146 -0.034573
# len_of_query               0.221767               0.063501  0.017572
# shared_words               1.000000               0.339178  0.320273
# frequency_words_in_sq      0.339178               1.000000  0.317115
# distance                   0.320273               0.317115  1.000000

# %%
training_data
# Out:
#            id  product_uid                                      product_title  \
# 0           2       100001                            Simpson StrongTie Angle
# 1           3       100001                            Simpson StrongTie Angle
# 2           9       100002  BEHR Premium Textured DeckOver Tugboat Wood Co...
# 3          16       100005  Delta Vero Shower Only Faucet Trim Kit Chrome ...
# 4          17       100005  Delta Vero Shower Only Faucet Trim Kit Chrome ...
# 5          18       100006  Whirlpool cu ft Over Range Convection Microwav...
# 6          20       100006  Whirlpool cu ft Over Range Convection Microwav...
# 7          21       100006  Whirlpool cu ft Over Range Convection Microwav...
# 8          23       100007  Lithonia Lighting Quantum Black LED Emergency ...
# 9          27       100009                    House Fara ft MDF Fluted Casing
# 10         34       100010                Valley View Industries Metal Stakes
# 11         35       100011  Toro Personal Pace Recycler Variable Speed Sel...
# 12         37       100011  Toro Personal Pace Recycler Variable Speed Sel...
# 13         38       100011  Toro Personal Pace Recycler Variable Speed Sel...
# 14         48       100012  Hampton Bay Caramel Simple Weave Bamboo Rollup...
# 15         51       100013  InSinkErator SinkTop Switch Single Outlet InSi...
# 16         65       100016  Sunjoy Calais ft ft ft Steel Tile Fabric Grill...
# 17         69       100017  MD Building Products Cloverleaf Aluminum Sheet...
# 18         75       100017  MD Building Products Cloverleaf Aluminum Sheet...
# 19         81       100017  MD Building Products Cloverleaf Aluminum Sheet...
# 20         85       100017  MD Building Products Cloverleaf Aluminum Sheet...
# 21         88       100019  House Fara Linear ft MDF Overlapping Wainscot ...
# 22         90       100019  House Fara Linear ft MDF Overlapping Wainscot ...
# 23         92       100019  House Fara Linear ft MDF Overlapping Wainscot ...
# 24        101       100019  House Fara Linear ft MDF Overlapping Wainscot ...
# 25        105       100019  House Fara Linear ft MDF Overlapping Wainscot ...
# 26        106       100019  House Fara Linear ft MDF Overlapping Wainscot ...
# 27        113       100021           Dual Spray Half Pattern PopUp Spray Head
# 28        114       100021           Dual Spray Half Pattern PopUp Spray Head
# 29        117       100022  Samsung cu ft Front Load Washer Steam White EN...
# ...       ...          ...                                                ...
# 74037  221398       206588  Cake Boss Decorating Tools Plastic Icing Bag S...
# 74038  221400       206589     Husky Universal PassThrough Mechanics Tool Set
# 74039  221401       206590       Crosley LaFayette Low Profile TV Stand Black
# 74040  221404       206593  RustOleum Automotive oz Special White Auto Tou...
# 74041  221405       206594  Foremost Tides Framed Pivot Shower Door Oil Ru...
# 74042  221407       206596                Bali CuttoSize Crown PVC Louver Set
# 74043  221408       206597  Home Fashion Technologies Solid Wood Louver Ex...
# 74044  221409       206598              Newport Coastal Photo Eye Replacement
# 74045  221411       206599              HYDRONIX Inline Coconut Carbon Filter
# 74046  221412       206600   Worx Nicd Hour Charger Grass TrimmerDISCONTINUED
# 74047  221413       206601  Tekk Protection White Vented Hard Hat Ratchet ...
# 74048  221415       206602  HyLite Glass Block Fixed Vinyl Windows Driftwo...
# 74049  221416       206603  Westinghouse ft Oil Rubbed Bronze Beaded Chain...
# 74050  221419       206606  BEHR Premium Plus Florentine Clay Zero VOC Int...
# 74051  221420       206607  Home Legend Palace Oak Light Thick Wide Length...
# 74052  221422       206609  Whitehaus Collection Isabella WallMounted Bath...
# 74053  221423       206610  Champion Power Equipment HP GasPowered SemiTra...
# 74054  221426       206613                          Everbilt White Wall Guard
# 74055  221427       206614  Daltile Villa Valleta Calais Springs Porcelain...
# 74056  221432       206619  Home Styles Stone Harbor Round Slate Tile Top ...
# 74057  221434       206621  Crown Bolt mm Internal Hex Socket CapHead Cap ...
# 74058  221443       206627                   Stainless TipOut Sink Front Tray
# 74059  221449       206631  Masonite New Haven Three Quarter Oval Lite Pri...
# 74060  221450       206632  Lilly Miller UltraGreen Gal Vitamin Plant Starter
# 74061  221455       206637  Schluter Rondec Stainless Steel Metal Degree O...
# 74062  221457       206638  Atlantic Windowpane CD DVD BluRay Games Maple ...
# 74063  221458       206639                   Philips Halogen Flood Light Bulb
# 74064  221463       206641  Schlage Camelot InActive Aged Bronze Handleset...
# 74065  221471       206648               Plastec Rose Garden Wall Decor Steel
# 74066  221473       206650  LICHTENBERG Pool Blue No Millennial Ryan Heath...
#
#                                    search_term  relevance  \
# 0                                 angl bracket       3.00
# 1                                    l bracket       2.50
# 2                                    deck over       3.00
# 3                             rain shower head       2.33
# 4                           shower onli faucet       2.67
# 5                                  convect otr       3.00
# 6                          microwav over stove       2.67
# 7                                     microwav       3.00
# 8                                  emerg light       2.67
# 9                                      mdf 3/4       3.00
# 10                                 steel stake       2.67
# 11               brigg and stratton lawn mower       3.00
# 12                                     gas mow       3.00
# 13                                 honda mower       2.00
# 14          hampton bay chestnut pull up shade       2.67
# 15                                      dispos       2.67
# 16                                grill gazebo       3.00
# 17                                  door guard       1.00
# 18                      metal plate cover gcfi       1.67
# 19                                radiat grate       2.33
# 20                               window screen       2.33
# 21                         1x1 rail decor wood       1.33
# 22                         4*8 beadboard panel       2.67
# 23                               4x8wood panel       2.33
# 24                                     mdf 4x8       1.33
# 25                         wainscot chair rail       2.33
# 26                        wainscot plank panel       2.33
# 27                              lawn sprkinler       2.00
# 28                          rainbird sprinkler       2.33
# 29                         platform for washer       2.67
# ...                                        ...        ...
# 74037                 plastic 3 piec nativ set       1.67
# 74038                pass through curtain ring       1.33
# 74039              crosley lafayett kf30024bwh       2.33
# 74040                         dremel auto rust       2.33
# 74041                 privaci glass pivot door       2.67
# 74042                alabast blind 39x72 alvin       1.67
# 74043      exterior shutter with movabl louver       3.00
# 74044                              lightsensor       2.67
# 74045                   bypass 12 water filter       1.33
# 74046                                  ni-2.4v       2.00
# 74047                       hard hat with mine       1.67
# 74048  replac a broken glass in a vinyl window       2.00
# 74049                 ceil fan with chain cord       1.00
# 74050                           florentin clay       2.33
# 74051                        trim a home light       2.00
# 74052                  whitehaus bathroom sinl       2.33
# 74053                       6.5 hp gas generat       2.33
# 74054                    splash guard for wall       2.00
# 74055              spicewood spring floor tile       1.67
# 74056                     laguna porcelin tile       2.00
# 74057                            m6 screw 90mm       2.67
# 74058                        sink tip-out tray       3.00
# 74059         fiberglass front door by masonit       3.00
# 74060                         starter fertillz       2.00
# 74061   rondec stainless steel 3/8 edg protect       3.00
# 74062                           tv riser glass       1.00
# 74063                        r20 halogen light       3.00
# 74064  schlage lock siena half dummi knob with       2.33
# 74065                         zen garden decor       3.00
# 74066               fine sheer curtain 63 inch       2.33
#
#                                      product_description  len_of_query  \
# 0      Not angles make joints stronger also provide c...             2
# 1      Not angles make joints stronger also provide c...             2
# 2      BEHR Premium Textured DECKOVER innovative soli...             2
# 3      Update bathroom Delta Vero SingleHandle Shower...             3
# 4      Update bathroom Delta Vero SingleHandle Shower...             3
# 5      Achieving delicious results almost effortless ...             2
# 6      Achieving delicious results almost effortless ...             3
# 7      Achieving delicious results almost effortless ...             1
# 8      The Quantum Adjustable LED Black Emergency Lig...             2
# 9      Get House Fara ft MDF Fluted Casing add elegan...             2
# 10     Valley View Industries Metal Stakes galvanized...             2
# 11     Recycler Personal Pace Variable Speed SelfProp...             5
# 12     Recycler Personal Pace Variable Speed SelfProp...             2
# 13     Recycler Personal Pace Variable Speed SelfProp...             2
# 14     The wide Caramel Simple Weave Rollup Bamboo Sh...             6
# 15     The InSinkErator SinkTop Switch Single Outlet ...             1
# 16     Make grilling great handsome functional grill ...             2
# 17     The MD Building Products Aluminum Cloverleaf N...             2
# 18     The MD Building Products Aluminum Cloverleaf N...             4
# 19     The MD Building Products Aluminum Cloverleaf N...             2
# 20     The MD Building Products Aluminum Cloverleaf N...             2
# 21     The House Fara Linear ft primed MDF Overlappin...             4
# 22     The House Fara Linear ft primed MDF Overlappin...             3
# 23     The House Fara Linear ft primed MDF Overlappin...             2
# 24     The House Fara Linear ft primed MDF Overlappin...             2
# 25     The House Fara Linear ft primed MDF Overlappin...             3
# 26     The House Fara Linear ft primed MDF Overlappin...             3
# 27     Installed parks backyards across globe Rain Bi...             2
# 28     Installed parks backyards across globe Rain Bi...             2
# 29     The Samsung cu ft Front Load Washer Steam Whit...             3
# ...                                                  ...           ...
# 74037  Have perfect trio decorating bags Cake Boss De...             5
# 74038  The Husky PassThrough Socket Ratchet Set virtu...             4
# 74039  Enhance living space Crosleys impeccablycrafte...             3
# 74040  RustOleum Automotive TouchUp aerosols ideal us...             3
# 74041  Whether designing new bathroom renovating curr...             4
# 74042  Bali CuttoSize Vertical Blinds offer beautiful...             4
# 74043  Instantly add value style home solid prime pin...             5
# 74044  This Newport Coastal Photo Eye Replacement con...             1
# 74045  If already inline filter want replacement high...             4
# 74046  Flexibility best The Worx Grass TrimmerEdger p...             1
# 74047  TEKK Protection Vented Pro Ratchet Hard Hat us...             4
# 74048  Excellent privacy decorative solution area hom...             8
# 74049  This Westinghouse Lighting Oil Rubbed Bronze B...             5
# 74050  BEHR Premium Plus Zero VOC SelfPriming Interio...             2
# 74051  Quarter round typically placed front existing ...             4
# 74052  Beautify bathroom powder room Whitehaus Isabel...             3
# 74053  The Champion Power Equipment semitrash pump po...             4
# 74054  The Everbilt Wall Guard helps prevent damage w...             4
# 74055  This daltile villa valleta calais springs porc...             4
# 74056  Stone Harbor Dining Set includes Large Round D...             3
# 74057  Crown Bolts metric socket cap screws ideal app...             3
# 74058  Add little luxury otherwise wasted space stain...             3
# 74059  Create inviting stylish entryway Masonite New ...             5
# 74060  Lilly Miller UltraGreen Vitamin Plant Starter ...             2
# 74061  The prefabricated corner Rondec eliminates nee...             6
# 74062  Atlantic Inc Uniquely designed maximum media s...             3
# 74063  Philips Energy Advantage lamps use less energy...             3
# 74064  The Schlage Camelot InActive Aged Bronze Handl...             7
# 74065  The Rose Garden inspired popular early century...             3
# 74066  No Millennial Ryan heathered texture semisheer...             5
#
#        shared_words  frequency_words_in_sq  distance
# 0                 3                     74        20
# 1                 3                     74        20
# 2                 6                    116        53
# 3                 7                     64        52
# 4                 7                     64        50
# 5                 6                    317        67
# 6                 7                    317        65
# 7                 6                    317        71
# 8                 8                     77        51
# 9                 6                     46        29
# 10                7                     74        25
# 11               16                    154        82
# 12               14                    154        93
# 13               14                    154        89
# 14                9                    243        32
# 15                7                     60        59
# 16                2                     90        43
# 17                7                     47        47
# 18                6                     47        43
# 19                6                     47        45
# 20                8                     47        46
# 21               10                     58        57
# 22                9                     58        57
# 23                9                     58        60
# 24                8                     58        65
# 25               11                     58        54
# 26               10                     58        54
# 27                1                    114        33
# 28                1                    114        33
# 29               12                    223        45
# ...             ...                    ...       ...
# 74037            10                    162        42
# 74038             6                     78        33
# 74039             2                    105        29
# 74040             3                     40        46
# 74041             4                    159        58
# 74042             4                    181        28
# 74043             4                     75        73
# 74044             5                     43        33
# 74045             4                     73        27
# 74046             3                    133        47
# 74047             7                     74        43
# 74048             4                     71        53
# 74049            11                    121        42
# 74050             7                     90        45
# 74051             5                     80        68
# 74052             5                     48        41
# 74053             3                     63        44
# 74054             5                     24        21
# 74055             5                    176        67
# 74056             9                    151        63
# 74057             4                     58        47
# 74058             2                     44        21
# 74059            14                    150        77
# 74060             6                     50        41
# 74061             4                     30        34
# 74062             2                     53        68
# 74063             4                     61        19
# 74064            11                    111        49
# 74065             3                     31        24
# 74066             5                     52        63
#
# [74067 rows x 10 columns]

# %%
#lets create new feature which will denote 
# training_data['test'] = training_data[['shared_words', 'frequency_words_in_sq']].apply(lambda row:row[1]+row[0],axis=1)

# %%
# training_data[['product_title','len_of_query','shared_words','frequency_words_in_sq','relevance', 'test']].corr()
training_data[['product_title','len_of_query','shared_words','frequency_words_in_sq','relevance', 'test']].corr()´

# %%
# %matplotlib inline
# r = training_data[training_data.search_term.str.contains('^\d+\s+?\w\s+?\d+$')]
# (r.relevance ).hist(bins=30)
# r.describe()
training_data.head(3)

# %%
df_all = training_data.drop(['search_term','product_description','product_title','test'],axis=1)

# %%
df_train = df_all.iloc[:num_train]
df_test = df_all.iloc[num_train:]
id_test = df_test['id']

y_train = df_train['relevance'].values
X_train = df_train.drop(['id','relevance'],axis=1).values
X_test = df_test.drop(['id','relevance'],axis=1).values

# %%
df_train.head(3)

# %%
rf = RandomForestRegressor(n_estimators=15, max_depth=6, random_state=0)
clf = BaggingRegressor(rf, n_estimators=4, max_samples=0.1, random_state=25)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# pd.DataFrame({"id": id_test, "relevance": y_pred}).to_csv('submission.csv',index=False)

# %% [markdown]
# Analysis of the Model

# %%
from nltk.metrics import edit_distance
from sklearn.preprocessing import StandardScaler

import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer('english')


df_train = pd.read_csv("../input/train.csv", encoding="ISO-8859-1")
df_test = pd.read_csv("../input/test.csv", encoding="ISO-8859-1")
attribute_data = pd.read_csv('../input/attributes.csv')
df_pro_desc = pd.read_csv('../input/product_descriptions.csv')



df_all = pd.concat((df_train, df_test), axis=0, ignore_index=True)

num_train = df_train.shape[0]

def str_stemmer(s):
    return " ".join([stemmer.stem(word) for word in s.lower().split()])

def str_common_word(str1, str2):
    return sum(int(str2.find(word)>=0) for word in str1.split())


df_all = pd.concat((df_train, df_test), axis=0, ignore_index=True)

df_all = pd.merge(df_all, df_pro_desc, how='left', on='product_uid')


############## apply stemming #####################
training_data['search_term'] = training_data['search_term'].map(lambda x:str_stemmer_title(x))
training_data['product_title'] = training_data['product_title'].map(lambda x:str_stemmer(x))

training_data['product_description'] = training_data['product_description'].map(lambda x:str_stemmer(x))
############## end stemming #####################

############## building custome feature, let's build a few of them before compare which one is the best ###########
training_data['len_of_query'] = training_data['search_term'].map(lambda x:len(x.split())).astype(np.int64)
training_data['shared_words'] = training_data[['search_term','product_description', 'product_title']].apply(lambda row:sum([str_common_word(*row[:-1]), str_common_word(*row[1:])]), axis=1).astype(np.int64)

# training_data['frequency_digits_in_sq']=training_data.product_description.str.count("\\d+")
training_data['frequency_words_in_sq'] = training_data.product_description.str.count("\\w+").astype(np.int64)
training_data["distance_levistein"] = training_data.loc[:, ["search_term","product_title"]].apply(lambda x: edit_distance(*x), axis=1).astype(np.int64)

training_data['length in product info'] = training_data[['product_title','product_description']].apply(lambda row:sum([len(*row[:-1]), len(*row[1:])]), axis=1).astype(np.int64)

df_all = df_all.drop(['search_term','product_title','product_description'],axis=1)


df_train = df_all.iloc[:num_train]
print('df_train',df_train)
df_test = df_all.iloc[num_train:]
print('df_test',df_test)
id_test = df_test['id']

y_train = df_train['relevance'].values
X_train = df_train.drop(['id','relevance'],axis=1).values
X_test = df_test.drop(['id','relevance'],axis=1).values

#### Feature to the same scale
scX = StandardScaler()
X_train = scX.fit_transform(X_train)
X_test = scX.fit_transform(X_test)

rf = RandomForestRegressor(n_estimators=4, max_depth=6, random_state=0)
clf = BaggingRegressor(rf, n_estimators=4, max_samples=0.1, random_state=25)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

pd.DataFrame({"id": id_test, "relevance": y_pred}).to_csv('submission.csv',index=False)

# %%
training_data[training_data.search_term.str.count('\\w+')<1]

# %%
training_data[training_data.relevance < 2]['product_title']

# %%
import numpy as np
 
 
# Get a text from the Brown Corpus
sentences = brown.sents('ca01')
 
print(sentences)
# [[u'The', u'Fulton', u'County', u'Grand', u'Jury', u'said', u'Friday', u'an', u'investigation', u'of', u"Atlanta's", u'recent', u'primary', u'election', u'produced', u'``', u'no', u'evidence', u"''", u'that', u'any', u'irregularities', u'took', u'place', u'.'], [u'The', u'jury', u'further', u'said', u'in', u'term-end', u'presentments', u'that', u'the', u'City', u'Executive', u'Committee', u',', u'which', u'had', u'over-all', u'charge', u'of', u'the', u'election', u',', u'``', u'deserves', u'the', u'praise', u'and', u'thanks', u'of', u'the', u'City', u'of', u'Atlanta', u"''", u'for', u'the', u'manner', u'in', u'which', u'the', u'election', u'was', u'conducted', u'.'], ...]
 
print(len(sentences))  #  98
 
# get the english list of stopwords
stop_words = stopwords.words('english')
 
def build_similarity_matrix(sentences, stopwords=None):
    # Create an empty similarity matrix
    S = np.zeros((len(sentences), len(sentences)))
 
 
    for idx1 in range(len(sentences)):
        for idx2 in range(len(sentences)):
#             if idx1 == idx2:
#                 continue
            if idx1 != idx2:
                S[idx1][idx2] = sentence_similarity(sentences[idx1], sentences[idx2], stop_words)
 
    # normalize the matrix row-wise
    for idx in range(len(S)):
        S[idx] /= S[idx].sum()
 
    return S
 
# S = build_similarity_matrix(sentences, stop_words)    
# print(S)

# %%
training_data[training_data.text_rank_sp > 0.01]

# %%
(training_data.text_rank_sp+1).hist(bins=30)
(training_data.relevance).hist(bins=30)
# (training_data.distance / training_data.frequency_words_in_sq).hist(bins=30)

# %%
training_data['test']=training_data['distance'] / training_data['frequency_words_in_sq']

# %%
import sklearn

# %%
training_data
